# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# My training data goes up to June 2024. I don’t have real-time internet access by default, so I can’t pull in post-cutoff events unless your platform has a browsing feature and you’ve enabled it.
#
# - For anything after mid-2024, I may not have up-to-date specifics.
# - If you need the latest information, use a browser or provide me a link/text to analyze, and I can help summarize or compare.
# - I can still help with background, concepts, and historical context up to 2024-06, and I can help craft search queries to find current info.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> dict[str, Any]:
    """Search the web for information"""
    return tavily_client.search(query)



web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Mayor_of_San_Francisco',
#    'title': 'Mayor of San Francisco - Wikipedia',
#    'content': 'There have been 45 individuals who have served as mayor in San Francisco since 1850, when California became a state following the American Conquest of California. Prior to the conquest, Californios served as Mayor of San Francisco during the Spanish and Mexican eras since 1779.\n\nThe current mayor is Democrat Daniel Lurie.\n\n## Elections\n\n[edit]\n\nMain articles: 1979 San Francisco mayoral election, 1995, 1999, 2003, 2007, 2011, 2015, 2018, 2019, and 2024 [...] ## Salary and benefits\n\n[edit]\n\nAs of 2024, the mayor is paid an annual salary of $364,582, the highest mayoral salary in the United States. Nine city public employees earned higher salaries than the mayor, including the chief investment officer and the managing director of the San Francisco Employees\' Retirement System, who oversee the city\'s pension plan. Current mayor Daniel Lurie decided to return all but $1 of his annual salary back to San Francisco. [...] | Seal of San Francisco |\n| Flag of San Francisco |\n| Incumbent Daniel Lurie since January 8, 2025 |\n| Government of San Francisco |\n| Style "Style (form of address)") | His Honor   Mr. Mayor |\n| Residence | No official residence |\n| Term length | Four years, renewable once |\n| Inaugural holder | John W. Geary |\n| Formation | 1850 |\n| Salary | $1 |\n| Website | Office of the Mayor |',
#    'score': 0.92652357,
#    'raw_content': None,
#    'id': '92cc3d-00'},
#   {'url': 'https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0',
#    'title': "San Francisco's new mayor is starting to unite the fractured city | AP News",
#    'content': 'Facebook\n Copy\n\n  Link copied\n Print\n Email\n X\n LinkedIn\n Bluesky\n Flipboard\n Pinterest\n Reddit\n\nMayor Daniel Lurie, left, takes the oath of office during his inauguration Wednesday, Jan. 8, 2025, in San Francisco. (AP Photo/Godofredo A. Vásquez, File)\n\n7 of 13 |  \n\nMayor Daniel Lurie, left, takes the oath of office during his inauguration Wednesday, Jan. 8, 2025, in San Francisco. (AP Photo/Godofredo A. Vásquez, File)\n\n7 of 13 [...] Mayor Daniel Lurie, left, takes the oath of office during his inauguration Wednesday, Jan. 8, 2025, in San Francisco. (AP Photo/Godofredo A. Vásquez, File)\n\n7 of 13 |  \n\nMayor Daniel Lurie, left, takes the oath of office during his inauguration Wednesday, Jan. 8, 2025, in San Francisco. (AP Photo/Godofredo A. Vásquez, File) [...] 7 of 13\n\nMayor Daniel Lurie, left, takes the oath of office during his inauguration Wednesday, Jan. 8, 2025, in San Francisco. (AP Photo/Godofredo A. Vásquez, File)\n\nShare\n\n Facebook\n Copy\n\n  Link copied\n Print\n Email\n X\n LinkedIn\n Bluesky\n Flipboard\n Pinterest\n Reddit\n\nMayor-elect Daniel Lurie, right, takes a photograph of his family while riding a cable car, before being inaugurated into office Wednesday, Jan. 8, 2025, in San Francisco. (AP Photo/Godofredo A. Vásquez, File)\n\n8 of 13 |',
#    'score': 0.8679453,
#    'raw_content': None,
#    'id': '99670a-01'},
#   {'url': 'https://en.wikipedia.org/wiki/Daniel_Lurie',
#    'title': 'Daniel Lurie',
#    'content
#    'score': 0.8173562,
#    'raw_content': None,
#    'id': 'e21a6e-04'}],
#  'response_time': 0.0,
#  'request_id': 'de00ba1f-2347-4821-ab9c-620c35ef6644'}

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco?', additional_kwargs={}, response_metadata={}, id='00d9d9f9-6a7b-43ec-89f9-8d0f11aa27e0'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 609, 'prompt_tokens': 133, 'total_tokens': 742, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E9VPa7rwIzoAa09xH4lJHAowLrv1X', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fd1fc-5da0-7b02-aec0-ca4975990fe1-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'Who is the current mayor of San Francisco 2026'}, 'id': 'call_JBYq4AelCtPwh8lXS6rz6woV', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 133, 'output_tokens': 609, 'total_tokens': 742, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}),
#  ToolMessage(content='{"query": "Who is the current mayor of San Francisco 2026", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://abc7news.com/amp/post/san-francisco-mayor-daniel-lurie-give-1st-state-city-address/18408744", "title": "San Francisco Mayor Daniel Lurie gives 1st State of the City address", "content": "Politics\\n\\n# Mayor Daniel Lurie touts SF in 1st State of the City address: \'People are proud to live here again\'\\n\\nKGO\\n\\nBy Monica Madden\\n\\nThursday, January 15, 2026\\n\\nSan Francisco Mayor Daniel Lurie delivered his first State of the City address, highlighting that the city is \\"on the rise.\\" [...] Report a correction or typo\\n\\nCopyright © 2026 KGO-TV. All Rights Reserved. [...] SAN FRANCISCO (KGO) -- San Francisco Mayor Daniel Lurie delivered his first State of the City address Thursday, pledging not just to bring the city back, but to \\"build something better.\\"", "score": 0.8742601, "raw_content": null, "id": "330e9d-00"}, {"url": "https://www.youtube.com/watch?v=LvoD21z_inM", "title": "Mayor Daniel Lurie\'s State of the City 2026", "content": "# Mayor Daniel Lurie\'s State of the City 2026\\n## SFGovTV\\n13900 subscribers\\n49 likes\\n\\n### Description\\n2854 views\\nPosted: 16 Jan 2026\\nWatch San Francisco\'s Mayor Daniel Lurie give his State of the City address. [...] down roots, where affordability isn\'t a barrier to the life you want to build. I\'m honored to introduce someone who is expanding programs that make San Francisco work for families like mine and building a city where the next generation of San Franciscans can truly flourish. Please welcome Mayor Daniel Lori. [applause] [applause] Ooh yeah. [music] Jump for joy. We\'re coming back. [applause] Jennifer, thank you. Thank you so much. Thank you for your commitment to our city and to making sure our [...] police chief. Paul paved the way for a new generation of leadership at the SFPD with the appointment of Police Chief Derek Louu. Chief Lou, who has been serving neighborhoods across our city for more than 20 years, understands that our recovery is directly tied to our ability to tackle the drug crisis and reduce drug dealing and drug use on our streets. Public safety is the foundation for San Francisco\'s recovery, and it will always be my north star as mayor. Now, we all know this. Homelessness", "score": 0.85567063, "raw_content": null, "id": "db0f6d-01"}, {"url": "https://www.sf.gov/departments--office-mayor", "title": "Office of the Mayor", "content": "See all news\\n\\nMayor Lurie Announces Appointments of Civic Leaders to City Boards, Commissions, and Key Roles July 31, 2026Mayor Lurie Signs Balanced Budget Strengthening San Francisco\'s Social Safety Net, Advancing City\'s Economic Recovery July 30, 2026Mayor Lurie Celebrates Five-Year Extension for Lyft Bike Program as San Francisco Reaches Record-High Bikeshare Ridership July 29, 2026 [...] ## About\\n\\nWe are here to provide exceptional core city services that enable every San Franciscan to live safe, healthy and productive lives.\\n\\nLearn more about us\\n\\n### Office of the Mayor\'s newsletter\\n\\nJoin the mailing list for our newsletter.Sign up for our newsletter\\n\\n### Mayor\\n\\nDaniel Lurie is the 46th Mayor of the City and County of San Francisco.\\n\\nImage 3: Mayor Daniel LurieDaniel Lurie Mayor\\n\\n## Contact information\\n\\n### Address\\n\\nCity Hall 1 Dr Carlton B. Goodlett Place\\n\\nRoom 200 [...] Visit us\\n\\nCity HallPermit Center\\n\\nFind contacts\\n\\nAgency\\n\\n# Office of the Mayor\\n\\nDaniel Lurie is the 46th Mayor of the City and County of San Francisco.\\n\\nImage 2: Image of Mayor Daniel Lurie\\n\\n## Mayor Daniel Lurie\\n\\nWe are here to provide exceptional core city services that enable every San Franciscan to live safe, healthy and productive lives.Read about Mayor Lurie\'s priorities", "score": 0.8170061, "raw_content": null, "id": "9da4e9-02"}, {"url": "https://en.wikipedia.org/wik ...
#  AIMessage(content='Daniel Lurie is the current mayor of San Francisco. He is the 46th mayor and took office in 2025. He delivered the State of the City address in January 2026. If you’d like the very latest status, I can check for any recent updates.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 834, 'prompt_tokens': 1750, 'total_tokens': 2584, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E9VPhQxK6cUSWf1Eim3uT3PiSFkMX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fd1fc-7c96-7551-859d-4995e3cdd936-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1750, 'output_tokens': 834, 'total_tokens': 2584, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r

# %%
from langchain.messages import AIMessage

for message in response['messages']:
    if isinstance(message, AIMessage):
        for field, value in message:
            print(f"{field}={value!r}")
        print()
# Out:
# content=''
# additional_kwargs={'refusal': None}
# response_metadata={'token_usage': {'completion_tokens': 609, 'prompt_tokens': 133, 'total_tokens': 742, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E9VPa7rwIzoAa09xH4lJHAowLrv1X', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}
# type='ai'
# name=None
# id='lc_run--019fd1fc-5da0-7b02-aec0-ca4975990fe1-0'
# tool_calls=[{'name': 'web_search', 'args': {'query': 'Who is the current mayor of San Francisco 2026'}, 'id': 'call_JBYq4AelCtPwh8lXS6rz6woV', 'type': 'tool_call'}]
# invalid_tool_calls=[]
# usage_metadata={'input_tokens': 133, 'output_tokens': 609, 'total_tokens': 742, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}
#
# content='Daniel Lurie is the current mayor of San Francisco. He is the 46th mayor and took office in 2025. He delivered the State of the City address in January 2026. If you’d like the very latest status, I can check for any recent updates.'
# additional_kwargs={'refusal': None}
# response_metadata={'token_usage': {'completion_tokens': 834, 'prompt_tokens': 1750, 'total_tokens': 2584, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E9VPhQxK6cUSWf1Eim3uT3PiSFkMX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}
# type='ai'
# name=None
# id='lc_run--019fd1fc-7c96-7551-859d-4995e3cdd936-0'
# tool_calls=[]
# invalid_tool_calls=[]
# usage_metadata={'input_tokens': 1750, 'output_tokens': 834, 'total_tokens': 2584, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}}
