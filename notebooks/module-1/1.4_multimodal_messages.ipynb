# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv
from langchain.agents import create_agent
from langchain.messages import HumanMessage

load_dotenv()
# Out:
# True

# %%
agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# Capital: Lunaris Prime (also known as Lunapolis)
#
# - Location: A sunlit arc along the southern polar rim near Shackleton Crater, perched where long lunar days create reliable power and long nights preserve water ice in shadowed basins.
# - Government: The seat of the Lunar Confederation, housing the Council of Phases and the Prime Steward who presides over inter-crater diplomacy and orbital relations with Earth and other lunar colonies.
# - City layout: A ringed metropolis built in stacked, hexagonal habitat arcs around a central spire known as the Crescent Gate. Outer districts are pressurized domes with agriculture and industry; inner districts are cultural and administrative hubs.
# - Architecture: Transparent ice-and-glass domes, basalt-printed towers, and solar-sail roofs that track the Sun. Internal biomes simulate Earth-like climates for farming and living spaces.
# - Landmarks:
#   - Crescent Gate: monumental entrance and ceremonial center.
#   - Dawn Spire: a tall observatory and communications hub linking Earth and Moon.
#   - Archive of Echoes: a vast library carved into a frozen cliff, storing lunar history and lunar-Earth diplomatic records.
#   - Lumen Promenade: a luminescent street where bioluminescent flora lights the way at night.
# - Economy: Helium-3 and water-ice extraction, solar energy farms, and 3D-printed construction materials; robotics and biotech clusters support the city.
# - Daily life: Residents live in gravity-eased habitats, with 1/6 g encouraging unusual sports and architecture. Power cycles follow the Sun’s rhythm, with long lighting phases during the day and reflective nights for rest and study.
# - Culture: A blend of Earthly traditions and lunar rituals—storytelling of the long night, two-sun festivals, and art that plays with light and shadow.
#
# If you’d like, I can expand Lunaris Prime with more history, notable residents, or a current event happening there.

# %% [markdown]
# ## Image input

# %%
from IPython.display import display
from ipywidgets import FileUpload

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'moon.png', 'type': 'image/png', 'size': 358916, 'content': <memory at 0x7d341d42df00>, 'last_modified': datetime.datetime(2026, 8, 8, 10, 56, 23, 46000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Here’s a portrait of a capital built around a single idea: knowledge as the city’s lifeblood. The capital in question centers on the hub called University Europa, so the city itself is a living campus.
#
# Name and essence
# - Europolis, capital of the Union of European Knowledge (UEK). A city that functions as a vast campus, research lab, and diplomatic forum all at once.
# - The core philosophy: learn, share, innovate, and defend access to education as a public good.
#
# Layout and skyline
# - The city unfolds in concentric rings around a central spire known as the Helion Tower, which serves as both observatory and transmitter for global educational networks.
# - Outer rings form layered districts: Governance, Research Arcology, Academic Commons, Market and Culture, and Habitat Arcologies.
# - Skybridges and transparent transit tubes weave between towers; at night the skyline glows with bioluminescent façades that pulse in time with lectures and debates.
#
# Architecture and tech
# - Buildings blend smart stone, self-healing glass, and bio-luminescent panels. Walls revise themselves to optimize light and climate.
# - The energy grid is a hybrid: solar lattice on every surface, tidal micro-plants where rivers run through, and a city-wide data lattice that channels surplus computing power to open-access labs.
# - Transportation is dominated by light-vein mag-rails, vertical lifts in every tower, and aerial pedestrian ribbons that allow safe, fast movement above street level.
#
# Governance and society
# - Europolis is governed by a council elected from the faculties of the Universidades Europa; the Chancellor-Director is a rotating academic leader who serves as the city’s chief administrator.
# - Education is embedded in daily life: neighborhoods host open classrooms where citizens and visitors attend mini-lectures, debates, or hands-on workshops.
# - Multilingual by design (English, French, German, Spanish, and Esperanto widely used), with real-time translation embedded in public displays and transport announcements.
#
# Culture, life, and festivals
# - The cultural heart beats in the Agora Market, a living plaza where researchers demo prototypes, artists perform, and philosophers hold spontaneous salons.
# - Daily life centers on study and collaboration: co-ops, journals, and open labs are as common as grocery stores.
# - Notable festivals include the Equinox Confluence (a city-wide think-tank, with interns leading crowd-sourced problem-solving), and the Night of Quiet Suns (a peaceful interlude when solar rooftops illuminate the city in amber hues and citizens read aloud to one another).
#
# Landmarks and districts
# - The Grand Bibliotheca: a spiraling library that houses not just books but living archives of experiments, failed studies, and data sanctuaries.
# - The Perennial Dome: a weather-controlled arena for public speaking, simulations, and collective decision-making simulations.
# - The Vox Bridge: a shimmering arc that carries voices, literally turning talk into a visible light pattern, used for open debates.
# - The River of Glass: a digital-waterway where citizens scroll ideas across its surface and projects crystallize in holographic form.
# - Campus Core: where the Universities Europa’s main campuses interlock—research labs, lecture halls, and studio spaces all accessible to residents and visitors alike.
#
# Economy and daily function
# - The city’s currency isn’t only money; it’s knowledge credits, data tokens, and skill hours—people earn and spend them by contributing to open projects, mentoring, or running community labs.
# - Open-access by policy: data generated here is shared globally, with privacy and ethical safeguards rather than proprietary lock-ins.
#
# Challenges and tensions
# - Balancing corporate sponsorship with public access: some districts wear the glow of partnerships, while others demand strict open-source norms.
# - AI governance and bias checks are daily topics in council meetings, classrooms, and cafes.
# - The city negotiates between rapid innovation and the need to protect privacy, consent, and citizen rights in a highly connected environment.
#
# A short vignette
# - At dawn, the Helion Tower unfurls a soft orange glow as the city-wide lecture network activates. A student from a coastal archipelago presents a fusion-energy concept via holo-scripts, while a retired professor from a mountain town streams a critique from a floating amphitheater. The Agora Market fills with aroma from fusion-cuisine stalls, where a physicist and a poet co-create a performance that becomes a spontaneous consensus about a shared future.
#
# If you’d like, I can tailor Europolis to a specific vibe (gritty cyberpunk, elegant utopia, post-scarcity agritecture, etc.), adjust its size or geography (coastal, inland, riverine), or write a scene set there—perhaps a council debate, a student hackathon, or a diplomatic summit on the Vox Bridge.

# %% [markdown]
# ## Audio input

# %%
import base64
import io
import time

import sounddevice as sd
from scipy.io.wavfile import write
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")

# %%
agent = create_agent(
    model='gpt-audio',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
