# %% [markdown]
# # PERSONAL CHEF

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from tavily import TavilyClient
from typing import Any

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> dict[str, Any]:
    """Search the web for information"""
    return tavily_client.search(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover chicken and rice. What can I make?")]},
    config
)

print(response['messages'][-1].content)
# Out:
# Nice! Leftover chicken and rice give you lots of tasty quick options. Here are some good fits I found:
#
# - Chicken Fried Rice (quick and classic)
#   - Why it fits: uses leftover chicken and cold rice, plus veggies and eggs.
#   - Time: about 15 minutes.
#   - Key notes: peas, carrots, green onions, garlic, soy sauce, sesame oil.
#   - Link: https://quickweeknightmeals.com/chicken-fried-rice
#
# - Leftover Chicken and Egg Fried Rice (another fried rice option)
#   - Why it fits: designed for leftovers; flexible with rice and veggies.
#   - Time: around 15–20 minutes.
#   - Key notes: adds eggs; easy with ready-to-use rice.
#   - Link: https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice
#
# - Rotisserie Chicken Fried Rice (rotisserie chicken handy)
#   - Why it fits: uses rotisserie or pre-cooked chicken; simple one-pan.
#   - Time: about 30 minutes.
#   - Key notes: often includes soy sauce, veggies; very pantry-friendly.
#   - Link: https://streetsmartnutrition.com/easy-weeknight-fried-rice
#
# - Easy One Pot Chicken and Rice (stovetop comfort dish)
#   - Why it fits: one-pot, uses chicken and rice, plus stock and veggies.
#   - Time: around 30 minutes.
#   - Key notes: good if you want a savory, warmer dish with minimal cleanup.
#   - Link: https://www.crunchycreamysweet.com/easy-one-pot-chicken-and-rice
#
# - Chicken and Rice Casserole (baked comfort meal)
#   - Why it fits: great for leftovers; turns rice and chicken into a creamy casserole.
#   - Time: roughly 35–45 minutes total (including baking).
#   - Key notes: often uses cream soup or cheese; adaptable with your toppings.
#   - Links:
#     - Crazy for Crust: https://www.crazyforcrust.com/chicken-and-rice-casserole
#     - The Country Cook: https://www.thecountrycook.net/chicken-and-rice-casserole
#     - Cleverly Simple: https://www.cleverlysimple.com/chicken-and-rice-casserole
#
# Would you like me to pull the full, step-by-step recipe instructions for any of these? If you tell me which option you prefer (and what you have on hand—eggs, soy sauce, veggies, dairy), I can tailor a plan and write out the full recipe.

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='5741f3a0-e491-4b6a-9546-448948c22b39'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 612, 'prompt_tokens': 199, 'total_tokens': 811, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E9YO67Nih7PJMcAtF1XiD0Qv1AAZj', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fd2aa-ef20-74f2-add9-773eb6050f1f-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'leftover chicken and rice recipe'}, 'id': 'call_TgFbltEja27sevKTjggjnczV', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken fried rice recipe'}, 'id': 'call_lenL2D59hHsvsGkC8HKhqJbt', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken and rice casserole recipe'}, 'id': 'call_2ioHoDbLgBcTpd1mn6ymuk88', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken and rice soup recipe'}, 'id': 'call_PUvxDS3uBuF8Ec1p3dg2AI45', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 199, 'output_tokens': 612, 'total_tokens': 811, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}}),
#               ToolMessage(content='{"query": "leftover chicken and rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.youtube.com/watch?v=OhI4SYVj80A", "title": "How to Make Chicken Fried Rice Like The Restaurant | Leftover Chicken | 15 min Quick & Easy Recipe", "content": "Chicken Fried Rice Recipe Ingredients (2 full or 4 side servings) \\n- 1 cup of leftover chicken (can use rotisserie chicken or chicken breast or thigh meat)\\n- 2 cup of leftover white rice cooked from the day before (jasmine rice preferred) \\n- 1 small yellow onion, diced\\n- 1 clove of garlic, diced\\n- 3 sprigs of green onion (scallion) \\n- 1 cup of mixed frozen vegetables \\n- 1 Tbsp oyster sauce \\n- 2 Tbsp soy sauce (or to taste)\\n- 1 tsp sesame oil \\n- 1 large egg, beaten [...] are you hungry and have leftover chicken in your fridge let me show you how to make this chicken fried rice that even the chinese takeaway would be jealous of let\'s get started [Music] start by dicing one cup of leftover chicken you can use rotisserie chicken or any other chicken you have in the fridge now here\'s the secret on how to make the best fried rice possible use two cups of cooked rice from the day before [Music] first up we\'ll dice one small onion about the size of the palm of your [...] Do you think chicken fried rice at the Chinese takeout (or takeaway) is overpriced, but you are craving that classic and comforting Chinese dish anyways. Let me show you my chicken fried rice recipe that is not only healthy, but quick, simple and easy to make. This recipe will surely rival your favourite Chinese restaurant’s takeaway, plus it won’t set you back nearly $10. This recipe uses leftover chicken AND leftover rice, and each step is cooked with care to ensure that you become the master", "score": 0.8900749, "raw_content": null, "id": "e4dabd-00"}, {"url": "https://iowagirleats.com/one-pot-chicken-and-rice", "title": "One Pot Chicken and Rice - Family Favorite Recipe", "content": "Scoop leftover Chicken and Rice into an airtight container, or individual sized storage containers then refrigerate. I don’t recommend freezing this dish. Even high quality cooked rice has the potential to become mushy once thawed and reheated from the freezer.\\n\\nI recommend you reheat in individual sized portions. Simply scoop the cold chicken and rice into a bowl from the refrigerator then reheat in the microwave in 30 second increments, stirring between increments until warmed through. [...] Stir in remaining 2 – 4 Tablespoons butter (however much you like!) then season with additional seasoned salt and pepper if necessary. Let the dish sit for 5 minutes to thicken and cool then scoop into bowls and serve.", "score": 0.8820324, "raw_content": null, "id": "ed9d28-01"}, {"url": "https://quickweeknightmeals.com/chicken-fried-rice", "title": "Chicken Fried Rice - Quick Weeknight Meals", "content": "Chicken Fried Rice\\n\\nSimple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.\\n\\nPrep Time 5 minutes\\n\\nCook Time 10 minutes\\n\\nTotal Time 15 minutes\\n\\n### Ingredients\\n\\n 1 teaspoon olive oil\\n 1 teaspoon sesame oil\\n 1 cup frozen peas and carrots mix\\n 4 green onions, sliced, divided\\n 2 cloves garlic, minced\\n 2 eggs, whisked\\n 3 cups cold white rice (make it the day before)\\n 1 ½ cups diced cooked chicken\\n 3 tablespoons soy sauce [...] Skip to primary navigation\\n Skip to primary sidebar\\n\\ngo to homepage\\n\\nPublished: | Modified: | Author: Amanda Livesay\\n\\n# Chicken Fried Rice\\n\\n Facebook\\n Twitter\\n\\nJump to Recipe\\n\\nSimple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.\\n\\nThis is my go to dinner when I don\'t feel like cooking. I almost always have leftover rice in the refrigerator and some leftover rotisserie chicken in the freezer. [...] It\ ...
#               ToolMessage(content='{"query": "chicken fried rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.youtube.com/watch?v=H_WZGtFyNjU", "title": "Chicken Fried Rice That Tastes Better Than Takeout — Ready in 15 Minutes!", "content": "Serves: 2 to 4 Prep time: 8 minutes Cook time: 7 minutes For the chicken and marinade: 1/2 , finely diced 2 large eggs, beaten 3 cups overnight", "score": 0.75027883, "raw_content": null, "id": "b5f7a5-00"}, {"url": "https://www.youtube.com/watch?v=EiGAyfLLy30&vl=en", "title": "15 Minute Easy Chicken Fried Rice That Will Change Your LIFE!", "content": "Get Written Recipes here! 15 Minute Easy Chicken Fried Rice That Will Change Your LIFE! 15 minutes???? This took me 2 hours but it was good.", "score": 0.4883572, "raw_content": null, "id": "2394d8-01"}], "response_time": 3.24, "request_id": "6c03636b-36e6-4cf6-98ff-2d6f572b5aaa"}', name='web_search', id='7a73e57b-7e01-4af5-8f7e-d8bb10d253c1', tool_call_id='call_lenL2D59hHsvsGkC8HKhqJbt'),
#               ToolMessage(content='{"query": "chicken and rice casserole recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://kentrollins.com/blogs/chicken/chicken-and-rice-casserole", "title": "Chicken and Rice Casserole – Kent Rollins", "content": "4. In a 9x13-inch casserole dish, or 12 inch Dutch oven, evenly pour the rice along the bottom of the pan. Place the chicken on top. Note: you can cut the chicken breasts in half for smaller pieces. Evenly spoon the onion mixture on top of the chicken. Evenly pour the soup on top.\\n5. Cover with a lid or tinfoil. Bake at 350 degrees for about 1 ½ hours, or until the internal temperature of the chicken is 165 degrees F. Serve warm. [...] Print Recipe  Pin\\n\\n## Chicken and Rice Casserole - Cowboy Kent Rollins\\n\\nServings  4 to 6 servings\\n\\nPrep Time   10 Minutes\\n\\nTotal Time   1 Hour 40 Minutes\\n\\nAuthor Cowboy Kent Rollins\\n\\n### Ingredients\\n\\n 4 chicken breasts \\n\\n  or boneless chicken thighs\\n 1 ½ cups white rice \\n\\n  uncooked\\n 1 10 oz  can cream of chicken soup, plus 1 ½ cans water\\n 1 stick butter\\n 1 yellow onion \\n\\n  finely chopped\\n 2 celery stalks\\n to taste Mesquite Smoke Seasoning\\n ⅓ cup chopped green chilies\\n\\n### Instructions [...] I\'m using a Dutch oven and cooking outside over hot coals. If you\'re baking inside, grab a casserole dish for the oven OR a Dutch oven - either will work.\\n\\nStart by covering the bottom of the casserole dish with the uncooked rice. Top with the chicken breasts, and spoon the onion/green chile mixture over the chicken. Pour over the broth and bake - covered - for about an hour and a half until the chicken is cooked through - to 165 degrees internally.", "score": 0.92684203, "raw_content": null, "id": "68cff5-00"}, {"url": "https://www.youtube.com/watch?v=maDXHZ5CMB8", "title": "I Could Eat This Everyday! Chicken and Rice Casserole", "content": "If you’re looking for the ultimate Chicken and Rice Casserole, this creamy, cheesy baked recipe is exactly what you need. Made with shredded chicken, long grain rice, cheddar cheese, cream of chicken soup, cream of mushroom soup, and savory seasonings, this classic comfort food dinner is perfect for busy weeknights or feeding a hungry family.\\n\\nThis isn’t dry chicken and rice. [...] broth, sliced mushrooms, cream of mushroom soup, one pack of French onion soup mix, garlic cloves chopped. We have our rice. I\'ve already rinsed it. Cheddar cheese, onions, smoked paprika and thyme. We have frozen carrots and peas here, and we have some milk. So, that\'s all you need. Let\'s get into it. All right, to get started, we\'re going to melt some butter. Once that butter melts, we\'re going to add our onions, our garlic, and we\'re going to sauté this for a few minutes until those onions [...] The rice cooks right in the casserole with chicken broth and milk, soaking up all that rich flavor. The French onion soup mix adds depth, while melted cheddar cheese creates that golden, bubbly top layer everyone loves.\\n\\nWhy This Chicken and Rice Casserole Works:\\n• Uses uncooked rice that bakes perfectly in the oven\\n• Creamy, cheesy, and full of flavor\\n• Easy one dish dinner\\n• Perfect for meal prep\\n• Budget friendly and family approved", "score": 0.9035075, "raw_content": null, "id": "7f2b2d-01"}, {"url": "https://www.youtube.com/watch?v=hVp2rxMsUNk", "title": "How to Make Chicken Rice Casserole | Get Cookin\' | Allrecipes", "content": "want the easiest dinner of all time how about the fastest to put together I\'ve got both in the all recipes top rated recipe for good old chicken and rice casserole this recipe is so user friendly that you can mix it together inside the casserole dish I feel like I\'m going to make a mess that way so I\'m going to throw it together in a bowl pour it in and pop it in the oven starting with just some plain boneless skinless chicken breast cubed up to that I\'m adding in the three favorite c ...
#               ToolMessage(content='{"query": "chicken and rice soup recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://detoxinista.com/chicken-and-rice-soup", "title": "Chicken and Rice Soup", "content": "### Ingredients\\n\\n 1 tablespoon olive oil\\n 1 small yellow onion , chopped\\n 4 medium carrots , peeled & chopped\\n 4 celery ribs , chopped\\n 3 garlic cloves , minced\\n 2 teaspoons dried thyme\\n 1 teaspoon dried oregano\\n ½ cup uncooked white rice\\n 6 cups water\\n 1 ½ pounds boneless skinless chicken thighs\\n 2 teaspoons fine sea salt\\n 1 teaspoon ground black pepper\\n\\n### Instructions [...] Add the olive oil to a large pot over medium-high heat and saute the onion, carrots, and celery until they soften, about 5 to 8 minutes. Then add in the garlic, thyme, and oregano and stir for 1 more minute.\\n Add in the water, rice, chicken, salt, and pepper. Bring the liquid to a boil over high heat.\\n Once the water is boiling lower the heat and cover the pot. Let the soup gently simmer until the chicken reaches an internal temperature of 165ºF about 15 to 20 minutes.", "score": 0.98302, "raw_content": null, "id": "7b8664-00"}, {"url": "https://www.youtube.com/watch?v=tCxCi2B6vdU", "title": "The BEST Chicken & Rice Soup EVER", "content": "so a little bit of that about a/2 cup or so of Mira and then we\'re going to add our chicken that we chopped up and we\'re going to wash one cup of rice add that in cover with lid 15 minutes you have yourself some soup all right so once we get the chicken in there I got some rinsed off or uh clean white rice here we\'re going to go ahead and add that in you can use long grain short grain whatever you got in the pantry will do just fine we\'re going to add that along with a/2 cup of heavy cream [...] Shopping List:\\n1 rotisserie chicken\\n2 smoked Turkey wings \\n8 cups chicken broth \\n1 cup diced carrots, onion, celery \\n1 cup washed rice \\n1/2 stick butter \\n1/4 cup flour \\n1 tbsp garlic\\nAp seasoning, red pepper flakes \\n1 tbsp Italian paste\\n1/4 cup heavy cream [...] cup of heavy cream bring that to a boil cover with a lid 15 minutes the rice should be done and SE with your soup and hopefully you\'re cold you want to make sure you stir it so that the rice doesn\'t stick to the bottom I kind of forgot my mine stick in a little bit but we\'ll make it work don\'t tell the wife enriched egg noodles Ferris sulfite thiamine mono nitrate riboflavin vegetable oil wheat flour soy protein concentrate soy protein isolate not sure what the difference is there uh got a", "score": 0.88822687, "raw_content": null, "id": "388d3a-01"}, {"url": "https://www.youtube.com/watch?v=clRB-_Xj5L0", "title": "Easy Homemade Chicken and Rice Soup Recipe |Easy Chicken Noodle Soup w/ Rice  Recipe", "content": "2 carrot stick to celery stalk \\n1/2 cup of rice\\n1 tablespoon complete seasoning\\n3 garlic cloves 1/4 cup \\n1/4 teaspoon salt\\n1/4 teaspoon pepper add more if needed\\n1 tablespoon chicken bouillon \\n1 tablespoon better than bouillon \\n1 tablespoon dill \\n1/2 tablespoon thyme\\n3 tablespoons fresh parsley \\n1 teaspoon time to tablespoon butter\\n6 and 1/2  cups chicken broth\\n1 tablespoon better than bouillon [...] hi everyone welcome and welcome back to another recipe today I\'m showing you guys how to make this homemade chicken and rice soup this soup is super flavorful and it\'s very easy to make this recipe can be made on a stove top or crock pot before we begin please take a moment to like this video if you enjoy and let\'s jump right into it all right here\'s a quick glance of all the ingredients I\'m using carrots celery onions the rice of course thyme Dill fresh parsley mint garlic chicken buan Salt [...] chicken buan Salt and Pepper complete seasoning better than buan base as well as the chicken breast you can use chicken thighs as well let\'s get started I\'m going to start by slicing ing the chicken breast right in the middle the ...
#               AIMessage(content='Nice! Leftover chicken and rice open up a bunch of tasty quick meals. Here are 5 solid options you can make, with what you’d typically need beyond the leftovers and a quick peek at the source:\n\n- Chicken Fried Rice (quick, one-pan)\n  - What it is: A fast, restaurant-y fried rice using your leftover chicken and cold rice, plus veggies and a splash of soy/sesame/oyster sauce.\n  - Extras you’ll likely need: onion, garlic, frozen peas/carrots, eggs, green onions, soy sauce, sesame oil, optional oyster sauce.\n  - Time: about 15 minutes.\n  - Source: Quick Weeknight Meals (chicken fried rice recipe)\n  - Link: https://quickweeknightmeals.com/chicken-fried-rice\n\n- One-Pot Chicken and Rice (stovetop comfort in one pan)\n  - What it is: A simple skillet dinner that cooks chicken, rice, and aromatics in one pot, using your cooked chicken and rice as the base.\n  - Extras you’ll likely need: onion, garlic, butter, broth, herbs/spices.\n  - Time: around 30 minutes.\n  - Source: Iowa Girl Eats (One Pot Chicken and Rice)\n  - Link: https://iowagirleats.com/one-pot-chicken-and-rice\n\n- Easy Chicken and Rice Casserole (baked, cozy)\n  - What it is: A cheesy, creamy casserole that starts with leftovers and bakes into a comforting family dish.\n  - Extras you’ll likely need: shredded cheese, cream soup or cream base, optional veggies.\n  - Time: about 35 minutes.\n  - Source: Crazy for Crust (EASY Chicken and Rice Casserole)\n  - Link: https://crazyforcrust.com/chicken-and-rice-casserole\n\n- Chicken and Rice Soup (hearty and soothing)\n  - What it is: A warming soup that uses chicken, rice, and veggies to build a comforting bowl.\n  - Extras you’ll likely need: onion, carrots, celery, garlic, thyme/oregano, chicken broth or water, salt/pepper.\n  - Time: about 40–60 minutes depending on method.\n  - Source: Detoxinista (Chicken and Rice Soup)\n  - Link: https://detoxinista.com/chicken-and-rice-soup\n\n- Easy Chicken and Rice Soup (another solid soup option)\n  - What it is: A straightforward soup with chicken and rice, built on a flavorful veggie sofrito and simple seasonings.\n  - Extras you’ll likely need: onion, carrot, celery, garlic, herbs, broth.\n  - Time: roughly 30–40 minutes.\n  - Source: The Kitchn (Easy Chicken and Rice Soup)\n  - Link: https://www.thekitchn.com/easy-chicken-and-rice-soup-at-home-253483\n\nWant me to pull the full step-by-step recipe instructions for any of these? If you tell me which option you’re leaning toward, I can give you a complete, tailored recipe with quantities and steps. Also, tell me what other ingredients you have (vegetables, dairy, sauces, spices) and I can tailor a plan around what’s in your kitchen.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2412, 'prompt_tokens': 6022, 'total_tokens': 8434, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1728, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E9YOH2e4rYhYPspd3m9N10K556XTZ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fd2ab-18b9-7c10-8ae5-e35049d15283-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6022, 'output_tokens': 2412, 'total_tokens': 8434, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1728}})]}

# %%
question = HumanMessage(content="yes, please give me the recipe instructions for the Chicken and Rice Soup")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='5741f3a0-e491-4b6a-9546-448948c22b39'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 612, 'prompt_tokens': 199, 'total_tokens': 811, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E9YO67Nih7PJMcAtF1XiD0Qv1AAZj', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fd2aa-ef20-74f2-add9-773eb6050f1f-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'leftover chicken and rice recipe'}, 'id': 'call_TgFbltEja27sevKTjggjnczV', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken fried rice recipe'}, 'id': 'call_lenL2D59hHsvsGkC8HKhqJbt', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken and rice casserole recipe'}, 'id': 'call_2ioHoDbLgBcTpd1mn6ymuk88', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken and rice soup recipe'}, 'id': 'call_PUvxDS3uBuF8Ec1p3dg2AI45', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 199, 'output_tokens': 612, 'total_tokens': 811, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}}),
#               ToolMessage(content='{"query": "leftover chicken and rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.youtube.com/watch?v=OhI4SYVj80A", "title": "How to Make Chicken Fried Rice Like The Restaurant | Leftover Chicken | 15 min Quick & Easy Recipe", "content": "Chicken Fried Rice Recipe Ingredients (2 full or 4 side servings) \\n- 1 cup of leftover chicken (can use rotisserie chicken or chicken breast or thigh meat)\\n- 2 cup of leftover white rice cooked from the day before (jasmine rice preferred) \\n- 1 small yellow onion, diced\\n- 1 clove of garlic, diced\\n- 3 sprigs of green onion (scallion) \\n- 1 cup of mixed frozen vegetables \\n- 1 Tbsp oyster sauce \\n- 2 Tbsp soy sauce (or to taste)\\n- 1 tsp sesame oil \\n- 1 large egg, beaten [...] are you hungry and have leftover chicken in your fridge let me show you how to make this chicken fried rice that even the chinese takeaway would be jealous of let\'s get started [Music] start by dicing one cup of leftover chicken you can use rotisserie chicken or any other chicken you have in the fridge now here\'s the secret on how to make the best fried rice possible use two cups of cooked rice from the day before [Music] first up we\'ll dice one small onion about the size of the palm of your [...] Do you think chicken fried rice at the Chinese takeout (or takeaway) is overpriced, but you are craving that classic and comforting Chinese dish anyways. Let me show you my chicken fried rice recipe that is not only healthy, but quick, simple and easy to make. This recipe will surely rival your favourite Chinese restaurant’s takeaway, plus it won’t set you back nearly $10. This recipe uses leftover chicken AND leftover rice, and each step is cooked with care to ensure that you become the master", "score": 0.8900749, "raw_content": null, "id": "e4dabd-00"}, {"url": "https://iowagirleats.com/one-pot-chicken-and-rice", "title": "One Pot Chicken and Rice - Family Favorite Recipe", "content": "Scoop leftover Chicken and Rice into an airtight container, or individual sized storage containers then refrigerate. I don’t recommend freezing this dish. Even high quality cooked rice has the potential to become mushy once thawed and reheated from the freezer.\\n\\nI recommend you reheat in individual sized portions. Simply scoop the cold chicken and rice into a bowl from the refrigerator then reheat in the microwave in 30 second increments, stirring between increments until warmed through. [...] Stir in remaining 2 – 4 Tablespoons butter (however much you like!) then season with additional seasoned salt and pepper if necessary. Let the dish sit for 5 minutes to thicken and cool then scoop into bowls and serve.", "score": 0.8820324, "raw_content": null, "id": "ed9d28-01"}, {"url": "https://quickweeknightmeals.com/chicken-fried-rice", "title": "Chicken Fried Rice - Quick Weeknight Meals", "content": "Chicken Fried Rice\\n\\nSimple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.\\n\\nPrep Time 5 minutes\\n\\nCook Time 10 minutes\\n\\nTotal Time 15 minutes\\n\\n### Ingredients\\n\\n 1 teaspoon olive oil\\n 1 teaspoon sesame oil\\n 1 cup frozen peas and carrots mix\\n 4 green onions, sliced, divided\\n 2 cloves garlic, minced\\n 2 eggs, whisked\\n 3 cups cold white rice (make it the day before)\\n 1 ½ cups diced cooked chicken\\n 3 tablespoons soy sauce [...] Skip to primary navigation\\n Skip to primary sidebar\\n\\ngo to homepage\\n\\nPublished: | Modified: | Author: Amanda Livesay\\n\\n# Chicken Fried Rice\\n\\n Facebook\\n Twitter\\n\\nJump to Recipe\\n\\nSimple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.\\n\\nThis is my go to dinner when I don\'t feel like cooking. I almost always have leftover rice in the refrigerator and some leftover rotisserie chicken in the freezer. [...] It\ ...
#               ToolMessage(content='{"query": "chicken fried rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.youtube.com/watch?v=H_WZGtFyNjU", "title": "Chicken Fried Rice That Tastes Better Than Takeout — Ready in 15 Minutes!", "content": "Serves: 2 to 4 Prep time: 8 minutes Cook time: 7 minutes For the chicken and marinade: 1/2 , finely diced 2 large eggs, beaten 3 cups overnight", "score": 0.75027883, "raw_content": null, "id": "b5f7a5-00"}, {"url": "https://www.youtube.com/watch?v=EiGAyfLLy30&vl=en", "title": "15 Minute Easy Chicken Fried Rice That Will Change Your LIFE!", "content": "Get Written Recipes here! 15 Minute Easy Chicken Fried Rice That Will Change Your LIFE! 15 minutes???? This took me 2 hours but it was good.", "score": 0.4883572, "raw_content": null, "id": "2394d8-01"}], "response_time": 3.24, "request_id": "6c03636b-36e6-4cf6-98ff-2d6f572b5aaa"}', name='web_search', id='7a73e57b-7e01-4af5-8f7e-d8bb10d253c1', tool_call_id='call_lenL2D59hHsvsGkC8HKhqJbt'),
#               ToolMessage(content='{"query": "chicken and rice casserole recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://kentrollins.com/blogs/chicken/chicken-and-rice-casserole", "title": "Chicken and Rice Casserole – Kent Rollins", "content": "4. In a 9x13-inch casserole dish, or 12 inch Dutch oven, evenly pour the rice along the bottom of the pan. Place the chicken on top. Note: you can cut the chicken breasts in half for smaller pieces. Evenly spoon the onion mixture on top of the chicken. Evenly pour the soup on top.\\n5. Cover with a lid or tinfoil. Bake at 350 degrees for about 1 ½ hours, or until the internal temperature of the chicken is 165 degrees F. Serve warm. [...] Print Recipe  Pin\\n\\n## Chicken and Rice Casserole - Cowboy Kent Rollins\\n\\nServings  4 to 6 servings\\n\\nPrep Time   10 Minutes\\n\\nTotal Time   1 Hour 40 Minutes\\n\\nAuthor Cowboy Kent Rollins\\n\\n### Ingredients\\n\\n 4 chicken breasts \\n\\n  or boneless chicken thighs\\n 1 ½ cups white rice \\n\\n  uncooked\\n 1 10 oz  can cream of chicken soup, plus 1 ½ cans water\\n 1 stick butter\\n 1 yellow onion \\n\\n  finely chopped\\n 2 celery stalks\\n to taste Mesquite Smoke Seasoning\\n ⅓ cup chopped green chilies\\n\\n### Instructions [...] I\'m using a Dutch oven and cooking outside over hot coals. If you\'re baking inside, grab a casserole dish for the oven OR a Dutch oven - either will work.\\n\\nStart by covering the bottom of the casserole dish with the uncooked rice. Top with the chicken breasts, and spoon the onion/green chile mixture over the chicken. Pour over the broth and bake - covered - for about an hour and a half until the chicken is cooked through - to 165 degrees internally.", "score": 0.92684203, "raw_content": null, "id": "68cff5-00"}, {"url": "https://www.youtube.com/watch?v=maDXHZ5CMB8", "title": "I Could Eat This Everyday! Chicken and Rice Casserole", "content": "If you’re looking for the ultimate Chicken and Rice Casserole, this creamy, cheesy baked recipe is exactly what you need. Made with shredded chicken, long grain rice, cheddar cheese, cream of chicken soup, cream of mushroom soup, and savory seasonings, this classic comfort food dinner is perfect for busy weeknights or feeding a hungry family.\\n\\nThis isn’t dry chicken and rice. [...] broth, sliced mushrooms, cream of mushroom soup, one pack of French onion soup mix, garlic cloves chopped. We have our rice. I\'ve already rinsed it. Cheddar cheese, onions, smoked paprika and thyme. We have frozen carrots and peas here, and we have some milk. So, that\'s all you need. Let\'s get into it. All right, to get started, we\'re going to melt some butter. Once that butter melts, we\'re going to add our onions, our garlic, and we\'re going to sauté this for a few minutes until those onions [...] The rice cooks right in the casserole with chicken broth and milk, soaking up all that rich flavor. The French onion soup mix adds depth, while melted cheddar cheese creates that golden, bubbly top layer everyone loves.\\n\\nWhy This Chicken and Rice Casserole Works:\\n• Uses uncooked rice that bakes perfectly in the oven\\n• Creamy, cheesy, and full of flavor\\n• Easy one dish dinner\\n• Perfect for meal prep\\n• Budget friendly and family approved", "score": 0.9035075, "raw_content": null, "id": "7f2b2d-01"}, {"url": "https://www.youtube.com/watch?v=hVp2rxMsUNk", "title": "How to Make Chicken Rice Casserole | Get Cookin\' | Allrecipes", "content": "want the easiest dinner of all time how about the fastest to put together I\'ve got both in the all recipes top rated recipe for good old chicken and rice casserole this recipe is so user friendly that you can mix it together inside the casserole dish I feel like I\'m going to make a mess that way so I\'m going to throw it together in a bowl pour it in and pop it in the oven starting with just some plain boneless skinless chicken breast cubed up to that I\'m adding in the three favorite c ...
#               ToolMessage(content='{"query": "chicken and rice soup recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://detoxinista.com/chicken-and-rice-soup", "title": "Chicken and Rice Soup", "content": "### Ingredients\\n\\n 1 tablespoon olive oil\\n 1 small yellow onion , chopped\\n 4 medium carrots , peeled & chopped\\n 4 celery ribs , chopped\\n 3 garlic cloves , minced\\n 2 teaspoons dried thyme\\n 1 teaspoon dried oregano\\n ½ cup uncooked white rice\\n 6 cups water\\n 1 ½ pounds boneless skinless chicken thighs\\n 2 teaspoons fine sea salt\\n 1 teaspoon ground black pepper\\n\\n### Instructions [...] Add the olive oil to a large pot over medium-high heat and saute the onion, carrots, and celery until they soften, about 5 to 8 minutes. Then add in the garlic, thyme, and oregano and stir for 1 more minute.\\n Add in the water, rice, chicken, salt, and pepper. Bring the liquid to a boil over high heat.\\n Once the water is boiling lower the heat and cover the pot. Let the soup gently simmer until the chicken reaches an internal temperature of 165ºF about 15 to 20 minutes.", "score": 0.98302, "raw_content": null, "id": "7b8664-00"}, {"url": "https://www.youtube.com/watch?v=tCxCi2B6vdU", "title": "The BEST Chicken & Rice Soup EVER", "content": "so a little bit of that about a/2 cup or so of Mira and then we\'re going to add our chicken that we chopped up and we\'re going to wash one cup of rice add that in cover with lid 15 minutes you have yourself some soup all right so once we get the chicken in there I got some rinsed off or uh clean white rice here we\'re going to go ahead and add that in you can use long grain short grain whatever you got in the pantry will do just fine we\'re going to add that along with a/2 cup of heavy cream [...] Shopping List:\\n1 rotisserie chicken\\n2 smoked Turkey wings \\n8 cups chicken broth \\n1 cup diced carrots, onion, celery \\n1 cup washed rice \\n1/2 stick butter \\n1/4 cup flour \\n1 tbsp garlic\\nAp seasoning, red pepper flakes \\n1 tbsp Italian paste\\n1/4 cup heavy cream [...] cup of heavy cream bring that to a boil cover with a lid 15 minutes the rice should be done and SE with your soup and hopefully you\'re cold you want to make sure you stir it so that the rice doesn\'t stick to the bottom I kind of forgot my mine stick in a little bit but we\'ll make it work don\'t tell the wife enriched egg noodles Ferris sulfite thiamine mono nitrate riboflavin vegetable oil wheat flour soy protein concentrate soy protein isolate not sure what the difference is there uh got a", "score": 0.88822687, "raw_content": null, "id": "388d3a-01"}, {"url": "https://www.youtube.com/watch?v=clRB-_Xj5L0", "title": "Easy Homemade Chicken and Rice Soup Recipe |Easy Chicken Noodle Soup w/ Rice  Recipe", "content": "2 carrot stick to celery stalk \\n1/2 cup of rice\\n1 tablespoon complete seasoning\\n3 garlic cloves 1/4 cup \\n1/4 teaspoon salt\\n1/4 teaspoon pepper add more if needed\\n1 tablespoon chicken bouillon \\n1 tablespoon better than bouillon \\n1 tablespoon dill \\n1/2 tablespoon thyme\\n3 tablespoons fresh parsley \\n1 teaspoon time to tablespoon butter\\n6 and 1/2  cups chicken broth\\n1 tablespoon better than bouillon [...] hi everyone welcome and welcome back to another recipe today I\'m showing you guys how to make this homemade chicken and rice soup this soup is super flavorful and it\'s very easy to make this recipe can be made on a stove top or crock pot before we begin please take a moment to like this video if you enjoy and let\'s jump right into it all right here\'s a quick glance of all the ingredients I\'m using carrots celery onions the rice of course thyme Dill fresh parsley mint garlic chicken buan Salt [...] chicken buan Salt and Pepper complete seasoning better than buan base as well as the chicken breast you can use chicken thighs as well let\'s get started I\'m going to start by slicing ing the chicken breast right in the middle the ...
#               AIMessage(content='Nice! Leftover chicken and rice open up a bunch of tasty quick meals. Here are 5 solid options you can make, with what you’d typically need beyond the leftovers and a quick peek at the source:\n\n- Chicken Fried Rice (quick, one-pan)\n  - What it is: A fast, restaurant-y fried rice using your leftover chicken and cold rice, plus veggies and a splash of soy/sesame/oyster sauce.\n  - Extras you’ll likely need: onion, garlic, frozen peas/carrots, eggs, green onions, soy sauce, sesame oil, optional oyster sauce.\n  - Time: about 15 minutes.\n  - Source: Quick Weeknight Meals (chicken fried rice recipe)\n  - Link: https://quickweeknightmeals.com/chicken-fried-rice\n\n- One-Pot Chicken and Rice (stovetop comfort in one pan)\n  - What it is: A simple skillet dinner that cooks chicken, rice, and aromatics in one pot, using your cooked chicken and rice as the base.\n  - Extras you’ll likely need: onion, garlic, butter, broth, herbs/spices.\n  - Time: around 30 minutes.\n  - Source: Iowa Girl Eats (One Pot Chicken and Rice)\n  - Link: https://iowagirleats.com/one-pot-chicken-and-rice\n\n- Easy Chicken and Rice Casserole (baked, cozy)\n  - What it is: A cheesy, creamy casserole that starts with leftovers and bakes into a comforting family dish.\n  - Extras you’ll likely need: shredded cheese, cream soup or cream base, optional veggies.\n  - Time: about 35 minutes.\n  - Source: Crazy for Crust (EASY Chicken and Rice Casserole)\n  - Link: https://crazyforcrust.com/chicken-and-rice-casserole\n\n- Chicken and Rice Soup (hearty and soothing)\n  - What it is: A warming soup that uses chicken, rice, and veggies to build a comforting bowl.\n  - Extras you’ll likely need: onion, carrots, celery, garlic, thyme/oregano, chicken broth or water, salt/pepper.\n  - Time: about 40–60 minutes depending on method.\n  - Source: Detoxinista (Chicken and Rice Soup)\n  - Link: https://detoxinista.com/chicken-and-rice-soup\n\n- Easy Chicken and Rice Soup (another solid soup option)\n  - What it is: A straightforward soup with chicken and rice, built on a flavorful veggie sofrito and simple seasonings.\n  - Extras you’ll likely need: onion, carrot, celery, garlic, herbs, broth.\n  - Time: roughly 30–40 minutes.\n  - Source: The Kitchn (Easy Chicken and Rice Soup)\n  - Link: https://www.thekitchn.com/easy-chicken-and-rice-soup-at-home-253483\n\nWant me to pull the full step-by-step recipe instructions for any of these? If you tell me which option you’re leaning toward, I can give you a complete, tailored recipe with quantities and steps. Also, tell me what other ingredients you have (vegetables, dairy, sauces, spices) and I can tailor a plan around what’s in your kitchen.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2412, 'prompt_tokens': 6022, 'total_tokens': 8434, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1728, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E9YOH2e4rYhYPspd3m9N10K556XTZ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fd2ab-18b9-7c10-8ae5-e35049d15283-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6022, 'output_tokens': 2412, 'total_tokens': 8434, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1728}}),
#               HumanMessage(content='yes, please give me the recipe instructions for the Chicken and Rice Soup', additional_kwargs={}, response_metadata={}, id='700b1875-e60a-4c07-b8ec-fa940cc79b45'),
#               AIMessage(content='Here’s a simple Chicken and Rice Soup that uses your leftovers (chicken and rice) and a few pantry basics. It’s hearty, cozy, and quick.\n\nLeftover Chicken and Rice Soup\nServings: 4–6\nTotal time: about 30–40 minutes\n\nIngredients\n- 2 tablespoons olive oil\n- 1 medium onion, diced\n- 2 celery stalks, diced\n- 2 carrots, diced\n- 3 garlic cloves, minced\n- 6 cups chicken broth (or 4 cups broth + 2 cups water)\n- 2 cups leftover cooked rice\n- 1 1/2 cups shredded leftover cooked chicken\n- 1 teaspoon dried thyme (or 1 tablespoon fresh thyme)\n- 1 bay leaf\n- 1/2 teaspoon salt (adjust to taste)\n- 1/4 teaspoon black pepper\n- Optional: 1/4 cup chopped fresh parsley\n- Optional: 1 tablespoon lemon juice or zest\n- Optional: 1/4 cup milk or cream for a creamier soup\n\nInstructions\n1) Sauté the aromatics:\n   - In a large pot, heat the olive oil over medium heat.\n   - Add the diced onion, celery, and carrot. Sauté 5–7 minutes until the vegetables are soft.\n   - Add the minced garlic and cook about 30 seconds until fragrant.\n\n2) Build the broth:\n   - Pour in the chicken broth.\n   - Add the thyme and bay leaf.\n   - Bring to a simmer.\n\n3) Simmer the vegetables:\n   - Let the pot simmer 10–15 minutes, until the vegetables are tender.\n\n4) Add chicken and rice:\n   - Stir in the shredded chicken and leftover rice.\n   - Simmer 5–8 minutes until everything is heated through. If your rice is already cold, keep it at a gentle simmer so it heats evenly without becoming mushy.\n\n5) Finish and brighten:\n   - Remove the bay leaf.\n   - Season with salt and pepper to taste.\n   - If using, stir in lemon juice or zest and chopped parsley for brightness.\n   - For a creamy version, stir in milk or cream off the heat and warm through.\n\n6) Serve:\n   - Ladle into bowls and enjoy hot. This soup keeps well in the fridge for 3–4 days.\n\nTips\n- If you have extra veggies (like peas or corn), feel free to add them in the simmer step.\n- If the soup feels too thick, add a splash more broth or water.\n- If you want a herby note, swap thyme for a mix of thyme and dill or parsley.\n\nWould you like me to tailor this to what you actually have on hand (any extra veggies, dairy, or herbs)? I can also format this as a printable recipe if you’d like.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2381, 'prompt_tokens': 6721, 'total_tokens': 9102, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1792, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 5888}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E9YSo0E7jNl3iVeaK3pvflEK1TCL3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fd2af-62e2-7031-b2ca-5c9f2f996ad0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6721, 'output_tokens': 2381, 'total_tokens': 9102, 'input_token_details': {'audio': 0, 'cache_read': 5888}, 'output_token_details': {'audio': 0, 'reasoning': 1792}})]}

# %%
pprint(response['messages'][-1].content)
# Out:
# ('Here’s a simple Chicken and Rice Soup that uses your leftovers (chicken and '
#  'rice) and a few pantry basics. It’s hearty, cozy, and quick.\n'
#  '\n'
#  'Leftover Chicken and Rice Soup\n'
#  'Servings: 4–6\n'
#  'Total time: about 30–40 minutes\n'
#  '\n'
#  'Ingredients\n'
#  '- 2 tablespoons olive oil\n'
#  '- 1 medium onion, diced\n'
#  '- 2 celery stalks, diced\n'
#  '- 2 carrots, diced\n'
#  '- 3 garlic cloves, minced\n'
#  '- 6 cups chicken broth (or 4 cups broth + 2 cups water)\n'
#  '- 2 cups leftover cooked rice\n'
#  '- 1 1/2 cups shredded leftover cooked chicken\n'
#  '- 1 teaspoon dried thyme (or 1 tablespoon fresh thyme)\n'
#  '- 1 bay leaf\n'
#  '- 1/2 teaspoon salt (adjust to taste)\n'
#  '- 1/4 teaspoon black pepper\n'
#  '- Optional: 1/4 cup chopped fresh parsley\n'
#  '- Optional: 1 tablespoon lemon juice or zest\n'
#  '- Optional: 1/4 cup milk or cream for a creamier soup\n'
#  '\n'
#  'Instructions\n'
#  '1) Sauté the aromatics:\n'
#  '   - In a large pot, heat the olive oil over medium heat.\n'
#  '   - Add the diced onion, celery, and carrot. Sauté 5–7 minutes until the '
#  'vegetables are soft.\n'
#  '   - Add the minced garlic and cook about 30 seconds until fragrant.\n'
#  '\n'
#  '2) Build the broth:\n'
#  '   - Pour in the chicken broth.\n'
#  '   - Add the thyme and bay leaf.\n'
#  '   - Bring to a simmer.\n'
#  '\n'
#  '3) Simmer the vegetables:\n'
#  '   - Let the pot simmer 10–15 minutes, until the vegetables are tender.\n'
#  '\n'
#  '4) Add chicken and rice:\n'
#  '   - Stir in the shredded chicken and leftover rice.\n'
#  '   - Simmer 5–8 minutes until everything is heated through. If your rice is '
#  'already cold, keep it at a gentle simmer so it heats evenly without becoming '
#  'mushy.\n'
#  '\n'
#  '5) Finish and brighten:\n'
#  '   - Remove the bay leaf.\n'
#  '   - Season with salt and pepper to taste.\n'
#  '   - If using, stir in lemon juice or zest and chopped parsley for '
#  'brightness.\n'
#  '   - For a creamy version, stir in milk or cream off the heat and warm '
#  'through.\n'
#  '\n'
#  '6) Serve:\n'
#  '   - Ladle into bowls and enjoy hot. This soup keeps well in the fridge for '
#  '3–4 days.\n'
#  '\n'
#  'Tips\n'
#  '- If you have extra veggies (like peas or corn), feel free to add them in '
#  'the simmer step.\n'
#  '- If the soup feels too thick, add a splash more broth or water.\n'
#  '- If you want a herby note, swap thyme for a mix of thyme and dill or '
#  'parsley.\n'
#  '\n'
#  'Would you like me to tailor this to what you actually have on hand (any '
#  'extra veggies, dairy, or herbs)? I can also format this as a printable '
#  'recipe if you’d like.')
