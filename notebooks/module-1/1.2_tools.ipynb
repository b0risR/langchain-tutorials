# %% [markdown]
# ## Tool definition

# %%
from pprint import pprint

from dotenv import load_dotenv
from langchain.agents import create_agent
from langchain.messages import AIMessage, HumanMessage
from langchain.tools import tool
from rich import print as rprint

load_dotenv()
# Out:
# True

# %%
@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
check = tool1.invoke({"x": 467})

check
# Out:
# 21.61018278497431

# %%
type(check)
# Out:
# float

# %%
square_root.invoke({"x": 467})

# %% [markdown]
# ## Adding to agents

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 467 is approximately 21.61018278497431. It’s an irrational number, so the decimal goes on without repeating.

# %%
rprint(response)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='What is the square root of 467?',
#             additional_kwargs={},
#             response_metadata={},
#             id='a6dfa61b-0d92-4c63-94d9-9ca97a535aea'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 1176,
#                     'prompt_tokens': 158,
#                     'total_tokens': 1334,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 1152,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-EP4Z3Z2rHnuCQ1QbZyJwq3zdBYFPF',
#                 'service_tier': 'default',
#                 'finish_reason': 'tool_calls',
#                 'logprobs': None
#             },
#             id='lc_run--01a0af1f-3041-7ba0-b67c-d85ecae99530-0',
#             tool_calls=[
#                 {
#                     'name': 'square_root',
#                     'args': {'x': 467},
#                     'id': 'call_our1bPPYLZmP77yXxyQZ4wtB',
#                     'type': 'tool_call'
#                 }
#             ],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 158,
#                 'output_tokens': 1176,
#                 'total_tokens': 1334,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 1152}
#             }
#         ),
#         ToolMessage(
#             content='21.61018278497431',
#             name='square_root',
#             id='1a741947-ac84-42dd-a1be-faf873ea6bde',
#             tool_call_id='call_our1bPPYLZmP77yXxyQZ4wtB'
#         ),
#         AIMessage(
#             content='The square root of 467 is approximately 21.61018278497431. It’s an irrational number, so the
# decimal goes on without repeating.',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 360,
#                     'prompt_tokens': 193,
#                     'total_tokens': 553,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 320,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-EP4ZBLfUcnlKRNiT8W3dcIGpjnJwG',
#                 'service_tier': 'default',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--01a0af1f-5459-7fe0-8d06-9d353aebac69-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 193,
#                 'output_tokens': 360,
#                 'total_tokens': 553,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 320}
#             }
#         )
#     ]
# }

# %%
from rich.pretty import pprint as rpprint
rpprint(response, indent_guides=True, expand_all=True)
# Out:
# {
# │   'messages': [
# │   │   HumanMessage(
# │   │   │   content='What is the square root of 467?',
# │   │   │   additional_kwargs={},
# │   │   │   response_metadata={},
# │   │   │   id='a6dfa61b-0d92-4c63-94d9-9ca97a535aea'
# │   │   ),
# │   │   AIMessage(
# │   │   │   content='',
# │   │   │   additional_kwargs={
# │   │   │   │   'refusal': None
# │   │   │   },
# │   │   │   response_metadata={
# │   │   │   │   'token_usage': {
# │   │   │   │   │   'completion_tokens': 1176,
# │   │   │   │   │   'prompt_tokens': 158,
# │   │   │   │   │   'total_tokens': 1334,
# │   │   │   │   │   'completion_tokens_details': {
# │   │   │   │   │   │   'accepted_prediction_tokens': 0,
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'reasoning_tokens': 1152,
# │   │   │   │   │   │   'rejected_prediction_tokens': 0
# │   │   │   │   │   },
# │   │   │   │   │   'prompt_tokens_details': {
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'cached_tokens': 0
# │   │   │   │   │   }
# │   │   │   │   },
# │   │   │   │   'model_provider': 'openai',
# │   │   │   │   'model_name': 'gpt-5-nano-2025-08-07',
# │   │   │   │   'system_fingerprint': None,
# │   │   │   │   'id': 'chatcmpl-EP4Z3Z2rHnuCQ1QbZyJwq3zdBYFPF',
# │   │   │   │   'service_tier': 'default',
# │   │   │   │   'finish_reason': 'tool_calls',
# │   │   │   │   'logprobs': None
# │   │   │   },
# │   │   │   id='lc_run--01a0af1f-3041-7ba0-b67c-d85ecae99530-0',
# │   │   │   tool_calls=[
# │   │   │   │   {
# │   │   │   │   │   'name': 'square_root',
# │   │   │   │   │   'args': {
# │   │   │   │   │   │   'x': 467
# │   │   │   │   │   },
# │   │   │   │   │   'id': 'call_our1bPPYLZmP77yXxyQZ4wtB',
# │   │   │   │   │   'type': 'tool_call'
# │   │   │   │   }
# │   │   │   ],
# │   │   │   invalid_tool_calls=[],
# │   │   │   usage_metadata={
# │   │   │   │   'input_tokens': 158,
# │   │   │   │   'output_tokens': 1176,
# │   │   │   │   'total_tokens': 1334,
# │   │   │   │   'input_token_details': {
# │   │   │   │   │   'audio': 0,
# │   │   │   │   │   'cache_read': 0
# │   │   │   │   },
# │   │   │   │   'output_token_details': {
# │   │   │   │   │   'audio': 0,
# │   │   │   │   │   'reasoning': 1152
# │   │   │   │   }
# │   │   │   }
# │   │   ),
# │   │   ToolMessage(
# │   │   │   content='21.61018278497431',
# │   │   │   name='square_root',
# │   │   │   id='1a741947-ac84-42dd-a1be-faf873ea6bde',
# │   │   │   tool_call_id='call_our1bPPYLZmP77yXxyQZ4wtB'
# │   │   ),
# │   │   AIMessage(
# │   │   │   content='The square root of 467 is approximately 21.61018278497431. It’s an irrational number, so the decimal goes on without repeating.',
# │   │   │   additional_kwargs={
# │   │   │   │   'refusal': None
# │   │   │   },
# │   │   │   response_metadata={
# │   │   │   │   'token_usage': {
# │   │   │   │   │   'completion_tokens': 360,
# │   │   │   │   │   'prompt_tokens': 193,
# │   │   │   │   │   'total_tokens': 553,
# │   │   │   │   │   'completion_tokens_details': {
# │   │   │   │   │   │   'accepted_prediction_tokens': 0,
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'reasoning_tokens': 320,
# │   │   │   │   │   │   'rejected_prediction_tokens': 0
# │   │   │   │   │   },
# │   │   │   │   │   'prompt_tokens_details': {
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'cached_tokens': 0
# │   │   │   │   │   }
# │   │   │   │   },
# │   │   │   │   'model_provider': 'openai',
# │   │   │   │   'model_name': 'gpt-5-nano-2025-08-07',
# │   │   │   │   'system_fingerprint': None,
# │   │   │   │   'id': 'chatcmpl-EP4ZBLfUcnlKRNiT8W3dcIGpjnJwG',
# │   │   │   │   'service_tier': 'default',
# │   │   │   │   'finish_reason': 'stop',
# │   │   │   │   'logprobs': None
# │   │   │   },
# │   │   │   id='lc_run--01a0af1f-5459-7fe0-8d06-9d353aebac69-0',
# │   │   │   tool_calls=[],
# │   │   │   invalid_tool_calls=[],
# │   │   │   usage_metadata={
# │   │   │   │   'input_tokens': 193,
# │   │   │   │   'output_tokens': 360,
# │   │   │   │   'total_tokens': 553,
# │   │   │   │   'input_token_details': {
# │   │   │   │   │   'audio': 0,
# │   │   │   │   │   'cache_read': 0
# │   │   │   │   },
# │   │   │   │   'output_token_details': {
# │   │   │   │   │   'audio': 0,
# │   │   │   │   │   'reasoning': 320
# │   │   │   │   }
# │   │   │   }
# │   │   )
# │   ]
# }

# %%
pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='a6dfa61b-0d92-4c63-94d9-9ca97a535aea'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1176, 'prompt_tokens': 158, 'total_tokens': 1334, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1152, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EP4Z3Z2rHnuCQ1QbZyJwq3zdBYFPF', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0af1f-3041-7ba0-b67c-d85ecae99530-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 'call_our1bPPYLZmP77yXxyQZ4wtB', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 158, 'output_tokens': 1176, 'total_tokens': 1334, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1152}}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='1a741947-ac84-42dd-a1be-faf873ea6bde', tool_call_id='call_our1bPPYLZmP77yXxyQZ4wtB'),
#  AIMessage(content='The square root of 467 is approximately 21.61018278497431. It’s an irrational number, so the decimal goes on without repeating.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 360, 'prompt_tokens': 193, 'total_tokens': 553, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EP4ZBLfUcnlKRNiT8W3dcIGpjnJwG', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0af1f-5459-7fe0-8d06-9d353aebac69-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 193, 'output_tokens': 360, 'total_tokens': 553, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 467}, 'id': 'call_our1bPPYLZmP77yXxyQZ4wtB', 'type': 'tool_call'}]

# %%
for message in response['messages']:
    if isinstance(message, AIMessage):
        for field, value in message:
            print(f"{field}={value!r}")
        print()
# Out:
# content=''
# additional_kwargs={'refusal': None}
# response_metadata={'token_usage': {'completion_tokens': 1176, 'prompt_tokens': 158, 'total_tokens': 1334, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1152, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EP4Z3Z2rHnuCQ1QbZyJwq3zdBYFPF', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}
# type='ai'
# name=None
# id='lc_run--01a0af1f-3041-7ba0-b67c-d85ecae99530-0'
# tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 'call_our1bPPYLZmP77yXxyQZ4wtB', 'type': 'tool_call'}]
# invalid_tool_calls=[]
# usage_metadata={'input_tokens': 158, 'output_tokens': 1176, 'total_tokens': 1334, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1152}}
#
# content='The square root of 467 is approximately 21.61018278497431. It’s an irrational number, so the decimal goes on without repeating.'
# additional_kwargs={'refusal': None}
# response_metadata={'token_usage': {'completion_tokens': 360, 'prompt_tokens': 193, 'total_tokens': 553, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EP4ZBLfUcnlKRNiT8W3dcIGpjnJwG', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}
# type='ai'
# name=None
# id='lc_run--01a0af1f-5459-7fe0-8d06-9d353aebac69-0'
# tool_calls=[]
# invalid_tool_calls=[]
# usage_metadata={'input_tokens': 193, 'output_tokens': 360, 'total_tokens': 553, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}
