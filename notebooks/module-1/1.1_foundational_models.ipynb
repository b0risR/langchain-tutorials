# %%
from pprint import pprint

from dotenv import load_dotenv
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langchain.messages import AIMessage, HumanMessage

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon has no government or permanent population, so it has no cities or capitals. If humans someday establish settlements, they’d decide what to call them—there’s no official capital now. (In fiction people sometimes invent names like “Lunopolis,” but that’s not real.)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 583, 'prompt_tokens': 13, 'total_tokens': 596, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E99Gq2gKkEs9eTIHbvGK4mDckdnB6', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fcce9-9fcb-7a31-8b33-64989b446055-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 583, 'total_tokens': 596, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon has no government or permanent population, so it has no cities or capitals. If humans someday establish settlements, they’d decide what to call them—there’s no official capital now. (In fiction people sometimes invent names like “Lunopolis,” but that’s not real.)

# %%
pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-E99Gq2gKkEs9eTIHbvGK4mDckdnB6',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 583,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 512,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 596}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    temperature=1.0      # Kwargs passed to the model
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital. If you’re thinking of a fictional universe, some sci‑fi works imagine a lunar capital (often called things like “Luna City” or similar), but that’s fictional. Want me to name examples from a particular book or film?

# %%
pprint(response.content)
# Out:
# ('There isn’t one. The Moon isn’t a country or government, so it has no '
#  'capital. If you’re thinking of a fictional universe, some sci‑fi works '
#  'imagine a lunar capital (often called things like “Luna City” or similar), '
#  'but that’s fictional. Want me to name examples from a particular book or '
#  'film?')

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
# model = init_chat_model(model="claude-sonnet-4-6")

# response = model.invoke("What's the capital of the Moon?")
# print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# [{'type': 'text', 'text': 'The Moon does not have a capital because it has no government, no countries, and no permanent human residents. \n\nUnder the **1967 Outer Space Treaty**, no nation can claim sovereignty over the Moon or any other celestial body, meaning it is considered the "province of all mankind." \n\nWhile various space agencies (like NASA with its Artemis program) and private companies have plans to establish research bases or habitats on the Moon in the future, these would be scientific outposts rather than political capitals.', 'extras': {'signature': 'EjQKMgERTTIPVEYHkQ0BDyQwWJs19DPWfno/WCmm6mg8ywMKfWF82GyTH5YkPl+/OC8ahL1H'}}]

# %%
pprint(response.text)
# Out:
# ('The Moon does not have a capital because it has no government, no countries, '
#  'and no permanent human residents. \n'
#  '\n'
#  'Under the **1967 Outer Space Treaty**, no nation can claim sovereignty over '
#  'the Moon or any other celestial body, meaning it is considered the "province '
#  'of all mankind." \n'
#  '\n'
#  'While various space agencies (like NASA with its Artemis program) and '
#  'private companies have plans to establish research bases or habitats on the '
#  'Moon in the future, these would be scientific outposts rather than political '
#  'capitals.')

# %% [markdown]
# ## Initialising and invoking an agent

# %%
agent = create_agent(model=model)

# %%
# agent = create_agent(model="claude-sonnet-4-6")

# %%
agent = create_agent("gpt-5-nano")

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='037aa633-f33e-425f-baac-97feb344e7a0'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country and has no government, so it has no capital or official cities.\n\nIf you’re joking or writing fiction, you could use a fictional capital name like:\n- Lunopolis\n- Selene City\n- Luna Prime\n- Apollonia\n- Artemis City\n\nWant help brainstorming a version that fits a particular vibe (hard sci-fi, utopian, noir, etc.)? I can tailor names and world-building details.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1001, 'prompt_tokens': 13, 'total_tokens': 1014, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 896, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E9Ip8D4N94x5SnlUtoeIEvS5TUp4C', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fcf1a-065c-7ad0-8f1a-1ed40e6f98bd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 1001, 'total_tokens': 1014, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 896}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital or official cities.
#
# If you’re joking or writing fiction, you could use a fictional capital name like:
# - Lunopolis
# - Selene City
# - Luna Prime
# - Apollonia
# - Artemis City
#
# Want help brainstorming a version that fits a particular vibe (hard sci-fi, utopian, noir, etc.)? I can tailor names and world-building details.

# %%
print(response['messages'][0].content)
# Out:
# What's the capital of the Moon?

# %%
pprint(response['messages'][-1].response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-E9Ip8D4N94x5SnlUtoeIEvS5TUp4C',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 1001,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 896,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 1014}}

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
                  AIMessage(content="The capital of the Moon is Luna City."),
                  HumanMessage(content="Interesting, tell me more about Luna City")]}
                  )

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='f08e380f-2374-4c8a-ac58-4144f21a4ab9'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='89dea501-67ab-47dd-8309-ac2daf99b1bc', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='2d4631f8-0551-423d-839a-8fe0cbac99cc'),
#               AIMessage(content='Luna City is a fictional concept—the capital of the Moon in a storytelling or game setting. There’s no real Luna City, but here’s a rich, plausible version you can use or adapt.\n\nOverview\n- Purpose: Administrative and cultural hub of a lunar nation/coalition, coordinating governance, research, trade, and culture for Moon settlements.\n- Location: A permanently sunlit rim of a polar crater or a high-latitude region chosen for sunlight, stable solar power, and access to subsurface water ice.\n- Governing idea: A Lunar Council (with representatives from major settlements) plus Earth advisory oversight. Strong emphasis on water/ice resource rights, science funding, and infrastructure development.\n\nGeography and infrastructure\n- Habitat design: A ring of pressurized habitations arranged in concentric districts around a central admin spine. Exterior is blasted with regolith shielding, interior uses basalt-printed walls, and radiation shielding blankets.\n- Energy: Solar farms at the sunlit rim of the crater; compact nuclear microreactors for emergency power; battery and fuel-cell buffers for long lunar nights (if the location isn’t perpetually sunlit).\n- Water and life support: Subsurface water ice mined from nearby deposits; closed-loop hydroponics for food; air revitalization and waste recycling are highly automated.\n- Transportation: Lightweight lunar rovers for short hops, a robotic tram or rail network within the city rings, and sky-lift drones for freight between districts and the spaceport.\n\nSociety and culture\n- Population: A diverse mix of Earth-born settlers, scientists, engineers, and administrators, with a strong culture of collaboration and resilience.\n- Language and education: Common lingua franca for administration and schooling, with planetary languages preserved in homes and schools; curricula emphasize lunar geology, robotics, life support systems, and planetary protection.\n- Daily life: A blend of high-tech efficiency and community life in domed parks and plazas; cultural events celebrate lunar science, Earth heritage, and interplanetary exploration.\n\nEconomy and technology\n- Main exports: Water ice, refined regolith minerals, and advanced in-situ manufacturing products. Scientific data and lunar samples are valuable too.\n- Research and industry: Astrobiology under dome farms, materials science from lunar regolith, and autonomous systems development. Tourism is possible in tightly managed, permitted zones.\n- Logistics: Regular transport links to Earth and other colonies; spaceport handles cargo, crew rotations, and research missions.\n\nLandmarks and districts (conceptual)\n- Administrative Ring: The core governance complex with the Lunar Council chambers and archives.\n- Archive Dome: A vast digital/physical library of lunar history, science data, and interplanetary diplomacy records.\n- Harvest Quarter: Mixed-use district with hydroponics facilities, markets, and educational farms.\n- Oculus Observatory: Large transparent dome with a sweeping view of the lunar surface and Earth rising; public programs and research use.\n- Helios Gate: The primary entry/exit point for lunar traffic, with customs, health checks, and logistics.\n- Market Crescent: A bustling hub for goods, culture, and informal gatherings; known for lunar crafts and nutrient lawns.\n- Spaceport Cluster: The main connection to Earth and other bodies; shuttles, cargo freighters, and maintenance yards.\n\nArchitecture and atmosphere\n- Aesthetics blend functional, modular design with awe-inspiring spaces: towering radiating hubs, glassy domes, and exposed regolith walkways protected by canopies.\n- Atmosphere: Fully pressurized, air-conditioned interiors with comfortable gravity (Moon’s gravity is about 1.62 m/s², restive for some travelers and comfortable for long-term habitation).\n- Climate control: Internal climates are stable; exterior operations occur in environments shielded from radiation and  ...

# %%
print(response['messages'][-1].content)
# Out:
# Luna City is a fictional concept—the capital of the Moon in a storytelling or game setting. There’s no real Luna City, but here’s a rich, plausible version you can use or adapt.
#
# Overview
# - Purpose: Administrative and cultural hub of a lunar nation/coalition, coordinating governance, research, trade, and culture for Moon settlements.
# - Location: A permanently sunlit rim of a polar crater or a high-latitude region chosen for sunlight, stable solar power, and access to subsurface water ice.
# - Governing idea: A Lunar Council (with representatives from major settlements) plus Earth advisory oversight. Strong emphasis on water/ice resource rights, science funding, and infrastructure development.
#
# Geography and infrastructure
# - Habitat design: A ring of pressurized habitations arranged in concentric districts around a central admin spine. Exterior is blasted with regolith shielding, interior uses basalt-printed walls, and radiation shielding blankets.
# - Energy: Solar farms at the sunlit rim of the crater; compact nuclear microreactors for emergency power; battery and fuel-cell buffers for long lunar nights (if the location isn’t perpetually sunlit).
# - Water and life support: Subsurface water ice mined from nearby deposits; closed-loop hydroponics for food; air revitalization and waste recycling are highly automated.
# - Transportation: Lightweight lunar rovers for short hops, a robotic tram or rail network within the city rings, and sky-lift drones for freight between districts and the spaceport.
#
# Society and culture
# - Population: A diverse mix of Earth-born settlers, scientists, engineers, and administrators, with a strong culture of collaboration and resilience.
# - Language and education: Common lingua franca for administration and schooling, with planetary languages preserved in homes and schools; curricula emphasize lunar geology, robotics, life support systems, and planetary protection.
# - Daily life: A blend of high-tech efficiency and community life in domed parks and plazas; cultural events celebrate lunar science, Earth heritage, and interplanetary exploration.
#
# Economy and technology
# - Main exports: Water ice, refined regolith minerals, and advanced in-situ manufacturing products. Scientific data and lunar samples are valuable too.
# - Research and industry: Astrobiology under dome farms, materials science from lunar regolith, and autonomous systems development. Tourism is possible in tightly managed, permitted zones.
# - Logistics: Regular transport links to Earth and other colonies; spaceport handles cargo, crew rotations, and research missions.
#
# Landmarks and districts (conceptual)
# - Administrative Ring: The core governance complex with the Lunar Council chambers and archives.
# - Archive Dome: A vast digital/physical library of lunar history, science data, and interplanetary diplomacy records.
# - Harvest Quarter: Mixed-use district with hydroponics facilities, markets, and educational farms.
# - Oculus Observatory: Large transparent dome with a sweeping view of the lunar surface and Earth rising; public programs and research use.
# - Helios Gate: The primary entry/exit point for lunar traffic, with customs, health checks, and logistics.
# - Market Crescent: A bustling hub for goods, culture, and informal gatherings; known for lunar crafts and nutrient lawns.
# - Spaceport Cluster: The main connection to Earth and other bodies; shuttles, cargo freighters, and maintenance yards.
#
# Architecture and atmosphere
# - Aesthetics blend functional, modular design with awe-inspiring spaces: towering radiating hubs, glassy domes, and exposed regolith walkways protected by canopies.
# - Atmosphere: Fully pressurized, air-conditioned interiors with comfortable gravity (Moon’s gravity is about 1.62 m/s², restive for some travelers and comfortable for long-term habitation).
# - Climate control: Internal climates are stable; exterior operations occur in environments shielded from radiation and micrometeoroids.
#
# Challenges and risks
# - Radiation and micrometeoroids: Robust shielding and protective protocols are standard.
# - Dust and abrasion: Electrostatic dust suppression and protective suits for surface work.
# - Resource balance: Maintaining water, oxygen, and energy supplies requires constant monitoring and rapid response to disruptions.
# - Social dynamics: Governance must balance Earth oversight with lunar autonomy to prevent tensions over resource rights and political influence.
#
# Story prompts and hooks (optional)
# - A sudden power outage cripples Luna City’s life-support systems; the council must decide whether to reroute power through a dangerous old reserve line.
# - An unexpected water-ice deposit is found beneath a political adversary’s property—sparking legal and diplomatic intrigue.
# - An independent settlement outside Luna City claims a “right to self-determine” their governance, challenging lunar law and provoking a constitutional crisis.
# - A routine scientific mission uncovers an artifact beneath the ice that hints at longer-term lunar habitation than previously believed.
#
# If you want, I can tailor Luna City to a specific tone (hard sci-fi realism, optimistic utopia, noir-detective vibe) or create a short novella-style scene set there. Would you prefer a more grounded, technically plausible version or a more fantastical, high-contrast setting?

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
    ):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional capital of the Moon (no real-world capital exists there). It’s a richly developed setting you can use for stories, games, or worldbuilding. Below is a detailed, self-contained concept you can adopt or adapt.
#
# Overview
# - Quick snapshot: Luna City sits on the rim of Shackleton Crater in the Moon’s south polar region. It’s the political, economic, and cultural heart of a Lunar Federation—an urban civilization built entirely in pressurized domes, tunnels, and hollowed lava tubes. Life is high-tech, resource-forward, and cosmopolitan, with Earth as both partner and distant audience.
# - Vibe: a sleek, utilitarian metropolis fused with grand public spaces, ice-blue lighting, and intricate subterranean networks. It’s at once austere (cold, vacuum-safety focused) and vibrant (festivals, markets, academic conferences, art in extreme environments).
#
# Geography and Location
# - Site: Rim of Shackleton Crater and adjacent permanently shadowed regions near the lunar south pole. Water ice and volatiles are close at hand, and rows of solar collectors soak up daylight on the crater’s sunlit ledges.
# - Why here: Access to water ice for life support and fuel, stable lighting for solar power, and a defensible, scenic landscape that has become symbolic for lunar independence and innovation.
# - Climate and life support: No atmosphere; everything is pressurized. Temperature swings are managed by insulated domes and buried infrastructure. Public life happens in glass and polymer domes connected by a network of tunnels and air bridges.
#
# Governance and politics
# - Political structure: Luna City is the political capital of a broader Lunar Federation (a cooperative of city-states and mining enclaves). The city hosts the central governing council, the executive directorate, and the federal ministries that manage water, energy, science, security, and culture.
# - Key bodies:
#   - The Luna City Council (legislative body) representing districts and districts’ special assemblies.
#   - The Office of the Prime Overseer (an executive role with a policy mandate rather than a monarchy-style throne).
#   - The Lunar Security Service (LSS) and Diplomatic Corps, coordinating with Earth-based governments and other off-world colonies.
# - Legal framework: A charter for interstellar trade, resource sharing, and civil rights in an environment with extreme living conditions. Disputes between districts or withEarth-backed corporations are settled by a Federal Arbitration Court housed in the Dome of Judgments.
#
# Economy and resources
# - Core sectors:
#   - Water ice mining and processing: extraction and purification of ice from shadowed craters, processed into water, fuel, and life-support chemicals.
#   - Energy: large solar farms on exposed surfaces and in orbit-fed power links; some regions host compact, shielded fusion or fission micro-reactors for baseline power.
#   - Manufacturing and construction: 3D printing and autonomous fabrication in vacuum-friendly environments; regolith processing turns rock into building materials.
#   - Research and development: advanced robotics, cryogenics, astrobiology, materials science, and terraforming-adjacent concepts (infrastructure for long-duration human presence).
#   - Tourism and culture: guided tours of ice caves, light festivals, zero-G experiences, and historical exhibitions about lunar exploration.
# - Trade: Earth-Lunar trade is crucial. Lunar commodities (water, oxygen, metals) fuel growth; high-value technologies and scientific data are often exchanged for Earth credits, science collaborations, or political concessions.
#
# Infrastructure and technology
# - Urban fabric: A lattice of pressurized domes, cryogenic storage rooms, and interconnected lava-tube tunnels. Architectural aesthetics favor translucent membranes, pale metals, and lighting that mimics Earth-day cycles.
# - Housing: Residential districts are modular and adaptable, built from roboticly assembled domes and 3D-printed components. Each district has its own microgrid of power and water recycling.
# - Transport within the city:
#   - Subsurface transit tubes: magnetically levitated capsule trains that zip between districts with low energy use.
#   - Surface shuttles: wheeled or hopper vehicles for short hops across crater rims.
#   - Pedestrian skywalks and air bridges connect major domes; few areas allow true surface walking due to regolith dust.
# - Public spaces: Parks and cultural quarters are designed as gravity-balanced zones with low-gravity gardens, glass observatories, and public art that glows with bioluminescent algae or phosphor-infused materials.
# - Safety systems: Redundant life-support loops, radiation shielding in every habitable zone, airlocks at every dome, and emergency evacuation routes through shielded tunnels.
#
# Districts and landmarks (sample layout)
# - Administrative Crescent: Seat of government, courts, and ministries. The Luna City Hall is a grand glass-and-titanium structure overlooking a central plaza.
# - Helios Basin: Industrial district with factories, 3D-printing fabs, and energy farms. Home to the city’s main water-ice processing facility.
# - Halo Quarter: Residential district with floating parks, low-gravity playgrounds, and family academies. Known for its community cooperatives.
# - Tranquility District: Embassy and diplomacy hub where Earth nations and lunar factions negotiate treaties; famous for the Lunar Forum Theater.
# - Sea of Serenity Market: The commercial heart with a sprawling market, artisanal shops, and floating eateries that serve meals using dehydrated lunar produce.
# - Aurora Dome: Arts, culture, and education complex. Opera house, planetarium, and the university’s main campus reside here.
# - Ice Gate District: Entry point for mineral shipments and ice harvesting facilities; a visually striking zone with ice towers and refrigeration tunnels.
#
# Notable sites
# - The Selene Spire: A communications and observation tower that doubles as a weather and orbital monitoring hub.
# - The Icewing Dome: A massive ice-processing dome that shimmers blue, visible from much of the city.
# - The Crater Gate: A ceremonial gate that marks the city’s formal boundary with the surrounding terrain.
# - The Lagrange Academy: A premier research university focusing on lunar geology, astrochemistry, and closed-loop life support systems.
# - The Night Market: A famous nocturnal bazaar that illuminates the polar night with bioluminescent art and solar-lit stalls.
#
# Culture, society, and daily life
# - Language and identity: A multilingual culture blending English, Mandarin, Russian, Spanish, Arabic, and local lunar colloquialisms. Public life emphasizes inclusivity, cooperative governance, and science literacy.
# - Education: Strong emphasis on STEM, with mandatory early exposure to water cycle management, radiation safety, and robotics. The University in Aurora Dome hosts international exchange programs with Earth universities.
# - Holidays and festivals: Lunar Light Festival (celebrating daylight and aurora-like glow effects inside domes), Ice Harvest Festival (celebrating supply wins and ice-sculpting competitions in the Crater Gate area), and Founders’ Week (honoring pioneers of lunar settlement and early missions).
# - Arts and media: A thriving scene for music, sculpture, and immersive theatre that uses projection on clear domes and soundscapes tuned for low gravity. Media often covers international collaboration with Earth and interplanetary partners.
#
# Science, research, and exploration
# - Ongoing projects: Cryo-biological research in controlled lunar environments, closed-loop ecology experiments, in-situ resource utilization (ISRU) tech, and surface robotics for exploration of nearby craters.
# - Collaboration: Regular joint missions with Earth space agencies and private firms; data and simulations shared through the Selene Spire’s network, with safeguards for dual-use tech.
# - The frontier: Expansion plans to extend the city’s underground tunnel network and build a secondary administrative hub closer to another water-rich crater, reducing transit times for officials and scientists.
#
# Security, defense, and peril
# - Security posture: The LSS maintains order, protects critical infrastructure, and coordinates search-and-rescue in harsh polar conditions. Security is designed to minimize the risk of cyber-physical threats to life-support systems.
# - Risks and challenges: Dust management in tunnels, radiation exposure, political friction with Earth-based powers, resource supply chain vulnerabilities, and the social strain of rapid urban growth in an extreme environment.
# - Disaster readiness: Redundant air-filtration loops, emergency shelter bays, and rapid evacuation corridors. Citizens train for life-support failures and natural events unique to the Moon’s environment.
#
# Potential story hooks and conflicts
# - A water-ice shipment is sabotaged, triggering a political scandal that tests the federation’s unity.
# - An alien or autonomous off-world drone is discovered near the Shackleton rim, stirring debates about lunar sovereignty and cooperation with Earth.
# - A massive solar flare threatens the city’s power grid and forces a city-wide blackout, revealing social fault lines between districts.
# - A controversial ISRU experiment causes unintended ecological effects inside a dome, challenging ethical boundaries in life-support tech.
#
# How to use Luna City in your project
# - Pick a tone: hard sci-fi (focus on engineering, ISRU, radiation shielding) or more romantic/optimistic (cultural fusion, architecture, festivals).
# - Decide the political flavor: is the Federation centralized, or is Luna City a beacon of independence with competing factions?
# - Create characters across districts: a government official, a factory foreperson, a university researcher, a market vendor, a security officer, and an artist in Aurora Dome.
# - Use district-specific flavor to ground scenes: an admin council hearing in Administrative Crescent, a night-market negotiation in Sea of Serenity Market, or a late-night lab session in Lagrange Academy.
#
# If you want, I can tailor Luna City to a particular vibe (grimdark, utopian, corporate-dominated, frontier-pioneering, etc.), or build a shorter/longer outline focusing on specific characters, conflicts, or events. Would you like a version aligned with a particular genre or a quick-start outline for a story or game session?
