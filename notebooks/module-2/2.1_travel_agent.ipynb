# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me the cheapest flight from San Francisco to Tokyo on november 25")]},
    config # type: ignore
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me the cheapest flight from San Francisco to Tokyo on november 25', additional_kwargs={}, response_metadata={}, id='91074d50-ecfa-4162-a2eb-a05f62c66dc7'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 501, 'prompt_tokens': 2812, 'total_tokens': 3313, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2688}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EABzrERVHsHPVIGDxqAjYrLMfIgwv', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fdbbe-2f38-72c0-8b33-291ef106e86b-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '25/11/2026', 'adults': 1, 'currency': 'EUR', 'locale': 'en'}, 'id': 'call_FI72ZA1VjpGX38XLgvOFVnk8', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2812, 'output_tokens': 501, 'total_tokens': 3313, 'input_token_details': {'audio': 0, 'cache_read': 2688}, 'output_token_details': {'audio': 0, 'reasoning': 448}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "query": "San Francisco → Tokyo on 25/11/2026, 1 adult",\n  "currency": "EUR",\n  "passengers": {\n    "adults": 1,\n    "children": 0,\n    "infants": 0\n  },\n  "resultsCount": 15,\n  "itineraries": [\n    {\n      "id": "0f9c1884512e000039ee4759_0|0f9c1884512e000039ee4759_1",\n      "price": 408.0,\n      "priceFormatted": "408 EUR",\n      "totalDurationSeconds": 40800,\n      "bookingUrl": "https://kiwi.com/u/bsr32x",\n      "imageId": "tokyo_jp",\n      "baggage": {\n        "personalItem": 1,\n        "cabinBag": 0,\n        "checkedBag": 0\n      },\n      "outbound": {\n        "from": "SFO",\n        "to": "NRT",\n        "departureTime": "2026-11-25T11:00:00",\n        "arrivalTime": "2026-11-26T15:20:00",\n        "durationSeconds": 40800,\n        "stops": 0,\n        "route": [\n          "SFO",\n          "NRT"\n        ],\n        "cabinClass": "Economy",\n        "segments": [\n          {\n            "from": "SFO",\n            "to": "NRT",\n            "fromCity": "San Francisco",\n            "toCity": "Tokyo",\n            "fromName": "San Francisco International",\n            "toName": "Narita International",\n            "fromCountry": "United States",\n            "toCountry": "Japan",\n            "departureTime": "2026-11-25T11:00:00",\n            "arrivalTime": "2026-11-26T15:20:00",\n            "durationSeconds": 40800,\n            "carrier": "NH",\n            "carrierName": "All Nippon Airways",\n            "flightNumber": "NH7",\n            "cabinClass": "Economy"\n          }\n        ]\n      },\n      "inbound": null\n    },\n    {\n      "id": "0f9c2133512e0000ba585be3_0|2133209f512f000033c29b03_0",\n      "price": 430.0,\n      "priceFormatted": "430 EUR",\n      "totalDurationSeconds": 124200,\n      "bookingUrl": "https://kiwi.com/u/fcnpf5",\n      "imageId": "tokyo_jp",\n      "baggage": {\n        "personalItem": 1,\n        "cabinBag": 0,\n        "checkedBag": 0\n      },\n      "outbound": {\n        "from": "SFO",\n        "to": "NRT",\n        "departureTime": "2026-11-25T09:15:00",\n        "arrivalTime": "2026-11-27T12:45:00",\n        "durationSeconds": 124200,\n        "stops": 1,\n        "route": [\n          "SFO",\n          "YVR",\n          "NRT"\n        ],\n        "cabinClass": "Economy",\n        "segments": [\n          {\n            "from": "SFO",\n            "to": "YVR",\n            "fromCity": "San Francisco",\n            "toCity": "Vancouver",\n            "fromName": "San Francisco International",\n            "toName": "Vancouver International",\n            "fromCountry": "United States",\n            "toCountry": "Canada",\n            "departureTime": "2026-11-25T09:15:00",\n            "arrivalTime": "2026-11-25T12:40:00",\n            "durationSeconds": 8700,\n            "carrier": "F8",\n            "carrierName": "Flair Airlines",\n            "flightNumber": "F81847",\n            "cabinClass": "Economy"\n          },\n          {\n            "from": "YVR",\n            "to": "NRT",\n            "fromCity": "Vancouver",\n            "toCity": "Tokyo",\n            "fromName": "Vancouver International",\n            "toName": "Narita International",\n            "fromCountry": "Canada",\n            "toCountry": "Japan",\n            "departureTime": "2026-11-26T11:30:00",\n            "arrivalTime": "2026-11-27T12:45:00",\n            "durationSeconds": 33300,\n            "carrier": "ZG",\n            "carrierName": "ZIPAIR",\n            "flightNumber": "ZG21",\n            "cabinClass": "Economy"\n          }\n        ]\n      },\n      "inbound": null\n    },\n    {\n      "id": "0f9c209f512e00007aad8588_0",\n      "price": 439.0,\n      "priceFormatted": "439 EUR",\n      "totalDurationSeconds": 40800,\n      "bookingUrl": "https://kiwi.com/u/cqd997",\n      "imageId": "tokyo_jp",\n      "baggage": {\n        "personalItem": 1,\n        "cabinBag": 1,\n        "checkedBag ...
#               AIMessage(content='Here’s the cheapest option I found for San Francisco (SFO) to Tokyo (NRT) on November 25, 2026 (1 adult):\n\n| Route | Times (Outbound) | Cabin | Price | Booking |\n|------|-------------------|-------|-------|---------|\n| SFO → NRT | 25 Nov 11:00 → 26 Nov 15:20 (11h 20m), nonstop | Economy | 408 EUR | https://kiwi.com/u/bsr32x |\n\nNotes:\n- This is a nonstop flight operated by All Nippon Airways (NH7), departure 25 Nov 2026 at 11:00 from SFO and arrival 26 Nov 2026 at 15:20 at Narita (NRT).\n- Baggage: personal item only (no cabin bag or checked bag included).\n\nBest price: 408 EUR\nShortest option (by duration): 11h 20m (this nonstop flight)\n\nRecommendation: Book the nonstop NH flight SFO → NRT on 25 Nov 2026 for the simplest and fastest option at the lowest price.\n\nFun fact about Tokyo: Shibuya Crossing in Tokyo is famous for its sea of pedestrians and is often cited as one of the busiest intersections in the world. Have a fantastic trip!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2069, 'prompt_tokens': 11160, 'total_tokens': 13229, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1792, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EAC05zUBvh8WsvAIyEim16gLfuloc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fdbbe-67b5-7430-b5ff-db131628ea25-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11160, 'output_tokens': 2069, 'total_tokens': 13229, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1792}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Here’s the cheapest option I found for San Francisco (SFO) to Tokyo (NRT) on November 25, 2026 (1 adult):
#
# | Route | Times (Outbound) | Cabin | Price | Booking |
# |------|-------------------|-------|-------|---------|
# | SFO → NRT | 25 Nov 11:00 → 26 Nov 15:20 (11h 20m), nonstop | Economy | 408 EUR | https://kiwi.com/u/bsr32x |
#
# Notes:
# - This is a nonstop flight operated by All Nippon Airways (NH7), departure 25 Nov 2026 at 11:00 from SFO and arrival 26 Nov 2026 at 15:20 at Narita (NRT).
# - Baggage: personal item only (no cabin bag or checked bag included).
#
# Best price: 408 EUR
# Shortest option (by duration): 11h 20m (this nonstop flight)
#
# Recommendation: Book the nonstop NH flight SFO → NRT on 25 Nov 2026 for the simplest and fastest option at the lowest price.
#
# Fun fact about Tokyo: Shibuya Crossing in Tokyo is famous for its sea of pedestrians and is often cited as one of the busiest intersections in the world. Have a fantastic trip!
