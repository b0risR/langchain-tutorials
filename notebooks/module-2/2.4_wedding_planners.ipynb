# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # 2.4 Wedding Planner
# In this lab you will build a multi-agent wedding planner.
#
# > Note: This lab has been updated since filming to make the agent performance more robust to errors and to limit run time. In particular: 1) added error handling for MCP failures, 2) limited the number of searches. It's worth noting that, where possible, tool errors should be returned to the agent rather than failing so that the agent can adjust its invocation and try again.

# %% [markdown]
# ## Setup Tools

# %%
import asyncio

from langchain_mcp_adapters.client import MultiServerMCPClient
from mcp.shared.exceptions import McpError
from mcp.types import CallToolResult, TextContent

RETRYABLE_MCP_CODES = {-32603}

class RetryMCPInterceptor:
    """Intercept MCP tool calls: retry transient failures, surface all errors gracefully.

    - Retryable McpError codes (e.g. -32603): retry with exponential backoff.
    - Non-retryable McpError codes (e.g. -32602): return error message immediately.
    - Any other exception (fetch failed, network errors, etc.): retry then return error message.
    """

    def __init__(self, max_retries: int = 3):
        self.max_retries = max_retries

    async def __call__(self, request, handler):
        last_error = None
        for attempt in range(self.max_retries):
            try:
                return await handler(request)
            except McpError as exc:
                last_error = exc
                print(f"[MCP interceptor] {type(exc).__name__} on {request.name} "
                      f"(code {exc.error.code}, attempt {attempt+1}/{self.max_retries}): {exc}")
                if exc.error.code not in RETRYABLE_MCP_CODES:
                    return CallToolResult(
                        content=[TextContent(type="text", text=f"Tool call failed (non-retryable): {exc}")],
                        isError=False,
                    )
            except Exception as exc:
                last_error = exc
                print(f"[MCP interceptor] {type(exc).__name__} on {request.name} "
                      f"(attempt {attempt+1}/{self.max_retries}): {exc}")

            if attempt < self.max_retries - 1:
                await asyncio.sleep(2 ** attempt)

        print(f"[MCP interceptor] all {self.max_retries} retries exhausted for {request.name}")
        return CallToolResult(
            content=[TextContent(type="text", text=f"Tool call failed after {self.max_retries} attempts: {last_error}")],
            isError=False,
        )

# %%
client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    },
    tool_interceptors=[RetryMCPInterceptor()],
)

tools = await client.get_tools()

# %%
from typing import Any

from langchain.tools import tool
from tavily import TavilyClient, TavilyError

tavily_client = TavilyClient()

@tool
def web_search(query: str, search_number: int, max_search_number: int) -> dict[str, Any]:
    """Search the web for information. You must track your search count by providing
    search_number (starting at 1) and max_search_number on every call.
    Queries must use only plain text characters. Do not use accented or special characters     
      (e.g., use 'capacite' instead of 'capacité').
    """
    if search_number > max_search_number:
        return {"message": "Search limit reached. Please summarize your findings and provide your final answer."}
    try:
        return tavily_client.search(query)
    except (TavilyError, ValueError, OSError) as e:
        return {"error": str(e)}

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

@tool
def query_playlist_db(query: str) -> str:

    """Query the database for playlist information"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error querying database: {e}"

# %% [markdown]
# ## Create State

# %%
from langchain.agents import AgentState


class WeddingState(AgentState):
    origin: str
    destination: str
    guest_count: str
    genre: str

# %% [markdown]
# ## Create Subagents

# %%
from langchain.agents import create_agent

# Travel agent
travel_agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt="""
    You are a travel agent. Search for flights to the desired destination wedding location.
    You are not allowed to ask any more follow up questions, you must find the best flight options based on the following criteria:
    - Price (lowest, economy class)
    - Duration (shortest)
    - Date (time of year which you believe is best for a wedding at this location)
    To make things easy, only look for one ticket, one way.
    You may need to make multiple searches to iteratively find the best options.
    You will be given no extra information, only the origin and destination. It is your job to think critically about the best options.
    If the MCP tool fails, returns malformed output, or does not give you usable flight results, try the tool again.
    Once you have found the best options, let the user know your shortlist of options.
    """
)

# %%
# Venue agent
venue_agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt="""
    You are a venue specialist. Search for venues in the desired location, and with the desired capacity.
    You are not allowed to ask any more follow up questions, you must find the best venue options based on the following criteria:
    - Price (lowest)
    - Capacity (exact match)
    - Reviews (highest)
    You may need to make multiple searches to iteratively find the best options. 
    You have a suggested limit of 12 web searches. Count every web_search call you make.
    After 12 searches, you should stop searching and summarize the best options you have
    found so far.
    """
)

# %%
# Playlist agent
playlist_agent = create_agent(
    model="gpt-5-nano",
    tools=[query_playlist_db],
    system_prompt="""
    You are a playlist specialist. Query the sql database and curate the perfect playlist for a wedding given a genre.
    Once you have your playlist, calculate the total duration and cost of the playlist, each song has an associated price.
    If you run into errors when querying the database, try to fix them by making changes to the query.
    Do not come back empty handed, keep trying to query the db until you find a list of songs.

    This is a SQLite database. Before writing any data queries, first discover the schema.
    """
)

# %% [markdown]
# ## Main Coordinator

# %%
from langchain.messages import HumanMessage, ToolMessage
from langchain.tools import ToolRuntime
from langgraph.types import Command


@tool
async def search_flights(runtime: ToolRuntime) -> str:
    """Travel agent searches for flights to the desired destination wedding location."""
    origin = runtime.state["origin"]
    destination = runtime.state["destination"]
    message = HumanMessage(content=f"Find flights from {origin} to {destination}")
    response = await travel_agent.ainvoke({"messages": [message]})
    return response['messages'][-1].content

@tool
def search_venues(runtime: ToolRuntime) -> str:
    """Venue agent chooses the best venue for the given location and capacity."""
    destination = runtime.state["destination"]
    capacity = runtime.state["guest_count"]
    query = f"Find wedding venues in {destination} for {capacity} guests"
    response = venue_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def suggest_playlist(runtime: ToolRuntime) -> str:
    """Playlist agent curates the perfect playlist for the given genre."""
    genre = runtime.state["genre"]
    query = f"Find {genre} tracks for wedding playlist"
    response = playlist_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def update_state(origin: str, destination: str, guest_count: str, genre: str, runtime: ToolRuntime) -> str:
    """Update the state when you know all of the values: origin, destination, guest_count, genre. 
    This tool must be called alone, without any other tool calls. It must complete and return to make,
    the information available to other tools."""
    return Command(update={
        "origin": origin, 
        "destination": destination, 
        "guest_count": guest_count, 
        "genre": genre, 
        "messages": [ToolMessage("Successfully updated state", tool_call_id=runtime.tool_call_id)]} # type: ignore
        )

# %%
from langchain.agents import create_agent

coordinator = create_agent(
    model="gpt-5-nano",
    tools=[search_flights, search_venues, suggest_playlist, update_state],
    state_schema=WeddingState,
    system_prompt="""
    You are a wedding coordinator. 
    First find all the information you need to update the state. When you have the information, update the state.
    Once that has completed and returned, you can delegate the tasks 
    to your specialists for flights, venues, and playlists.
    Once you have received their answers, coordinate the perfect wedding for me.
    """
)

# %% [markdown]
# ## Test

# %%
from langchain.messages import HumanMessage

message = HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre")

response = await coordinator.ainvoke(
    {
        "messages": [message],
    },
    config={"tags": ["WP"], "recursion_limit": 40},  #tag traces to make them easy to find in Langsmith. Increase number of steps the agent can take to 40.
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'destination': 'Paris',
#  'genre': 'Jazz',
#  'guest_count': '100',
#  'messages': [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre", additional_kwargs={}, response_metadata={}, id='97434f59-e891-47a9-9282-57df30738403'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 676, 'prompt_tokens': 336, 'total_tokens': 1012, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EAFLIPPcIRD6E7xsUU23U06rotjoo', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fdc82-6a8d-7093-b1ee-a5256b199450-0', tool_calls=[{'name': 'update_state', 'args': {'origin': 'London', 'destination': 'Paris', 'guest_count': '100', 'genre': 'Jazz'}, 'id': 'call_EuTRNwCZ5jmY4bBrY5Y4x5hV', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 336, 'output_tokens': 676, 'total_tokens': 1012, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#               ToolMessage(content='Successfully updated state', name='update_state', id='16326b8b-214e-41f1-a78a-9eebc42d5fa2', tool_call_id='call_EuTRNwCZ5jmY4bBrY5Y4x5hV'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 380, 'total_tokens': 394, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EAFLOyNwLCuPGpDC2zZToS1P8QS1h', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fdc82-87cc-7701-a319-015cc04af75d-0', tool_calls=[{'name': 'search_flights', 'args': {}, 'id': 'call_0yHTXJHXNSMvyKDKmqwbZPei', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 380, 'output_tokens': 14, 'total_tokens': 394, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Here are the best one-way flight options from London to Paris based on price, shortest duration, and a sensible travel date for a wedding season.\n\nCheapest options (64 EUR) - outbound only, Economy\n- Option 1\n  - Route: LTN → CDG\n  - Times (local): 15 Jun 19:10 → 15 Jun 21:30\n  - Duration: 1h20m\n  - Cabin: Economy\n  - Price: 64 EUR\n  - Booking: https://kiwi.com/u/hf7f49\n  - Notes: Direct flight, easyJet, flight U22439\n- Option 2\n  - Route: LTN → CDG\n  - Times (local): 15 Jun 07:05 → 09:30\n  - Duration: 1h25m\n  - Cabin: Economy\n  - Price: 64 EUR\n  - Booking: https://kiwi.com/u/xrg6tq\n  - Notes: Direct flight, easyJet, flight U22433\n- Option 3\n  - Route: LTN → CDG\n  - Times (local): 15 Jun 12:30 → 14:55\n  - Duration: 1h25m\n  - Cabin: Economy\n  - Price: 64 EUR\n  - Booking: https://kiwi.com/u/8ygvtst\n  - Notes: Direct flight, easyJet, flight U22437\n- Option 4\n  - Route: LTN → CDG\n  - Times (local): 14 Jun 19:40 → 22:00\n  - Duration: 1h20m\n  - Cabin: Economy\n  - Price: 64 EUR\n  - Booking: https://kiwi.com/u/8mmqm5\n  - Notes: Direct flight, easyJet, flight U22439\n\nShortest duration option (65 EUR) - outbound only, Economy\n- SEN → CDG\n  - Times (local): 10 Jun 10:10 → 12:20\n  - Duration: 1h10m\n  - Cabin: Economy\n  - Price: 65 EUR\n  - Booking: https://kiwi.com/u/r3hzg6\n  - Notes: Direct flight, easyJet, flight U25711; London Southend (SEN) to Charles de Gaulle (CDG)\n\nDate guidance for a wedding trip to Paris\n- Best time of year: Late spring to early summer (May–June) offers pleasant weather and classic Paris ambiance for weddings.\n- Practical window based on options above: around 10–16 June 2027. This window aligns with the 64 EUR weekend/weekday options and several direct LDW (London–Paris) services in the results.\n- If you want a broader window, you can consider early September as another excellent wedding-season month.\n\nRecommendation\n- If your top priority is the lowest price, choose any of the 64 EUR LTN → CDG options (e.g., 07:05 or 12:30 departures) for strong value with direct service.\n- If you prioritize the absolute shortest flight time, the 65 EUR SEN → CDG option (10:10–12:20) is the quickest, albeit slightly more expensive.\n- Given you’re aiming for a wedding trip, I’d suggest the 64 EUR LTN → CDG options around mid-June for best balance of price and schedule, with a fallback to the SEN option if you specifically want the shortest duration.\n\nHave a wonderful trip! Fun fact: Paris is known as the City of Light (La Ville Lumière) because it was one of the first major European cities to adopt street lighting, and it became a hub of enlightenment ideas in the 18th century.', name='search_flights', id='49072541-b253-47ee-bb92-cf1cfac9e6ca', tool_call_id='call_0yHTXJHXNSMvyKDKmqwbZPei'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 690, 'prompt_tokens': 1201, 'total_tokens': 1891, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EAFMQa01YII2qNRr2sq0YCh8Btcxc', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fdc83-80db-7e81-9ecf-1ce8fb7fb71f-0', tool_calls=[{'name': 'search_venues', 'args': {}, 'id': 'call_8TanI9YzpMwXEG1wCXKTKlso', 'type': 'tool_call'}, {'name': 'suggest_playlist', 'args': {}, 'id': 'call_KlgfL0fAb2r1RJ9n30Sc0FI2', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1201, 'output_tokens': 690, 'total_tokens': 1891, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#               ToolMessage(content='Here are Paris wedding venues that can host around 100 guests, listed with price guidance and notes on reviews. Ranked roughly by price (lowest first) among exact- or clearly 100-capacity options.\n\n- Le Camondo (Paris)\n  - Capacity: 100\n  - Price: from about €1,000 up to €8,400 (range shown in listings)\n  - Reviews: data not shown in the snippet, but listed on Bridebook\n  - Source: Bridebook listing\n\n- Maison Vivart (via ABC Salles)\n  - Capacity: 2–100 guests (can privatize for 100)\n  - Price: from about €2,200\n  - Reviews: not shown in snippet\n  - Source: ABC Salles listing\n\n- La Maison de Charly (Paris)\n  - Capacity: 100\n  - Price: €4,000–€6,000\n  - Reviews: 6 reviews listed on Bridebook\n  - Source: Bridebook\n\n- Hôtel Rochechouart (Paris)\n  - Capacity: 100\n  - Price: from about €4,000\n  - Reviews: 1 review listed on Bridebook\n  - Source: Bridebook\n\n- The Peninsula Paris\n  - Capacity: up to 100 (ballroom options for ~100 guests)\n  - Price: not disclosed in the Bridebook listing; official site confirms 100-capacity spaces\n  - Reviews: generally strong (not all details shown in snippet)\n  - Source: The Peninsula Paris official pages\n\nNotes\n- The exact capacity wording varies by venue (some list “up to 100,” others list “100” as a set capacity with flexibility for private dining). All of the above can accommodate around 100 guests for a wedding.\n- Price ranges depend on exact date, season, catering, and package inclusions. Higher-end hotels (Peninsula, Le Crillon) may not publish a simple base price; quotes are typically requested.\n- If you’d like, I can pull direct contact links and current availability for the top few options and outline a quick shortlist with next steps for viewing and quoting.', name='search_venues', id='8e665e58-dd5f-4bc7-8674-fbab84f97b74', tool_call_id='call_8TanI9YzpMwXEG1wCXKTKlso'),
#               ToolMessage(content="Here’s a wedding-friendly Jazz playlist curated from the Jazz tracks I found. It blends smooth bossa-nova classics with easy-going jazz to keep guests relaxed and dancing later on.\n\n1) Angela — Antônio Carlos Jobim — Album: Warner 25 Anos — Jazz — 2:50 — $0.99\n2) Garota De Ipanema — Antônio Carlos Jobim — Album: Warner 25 Anos — Jazz — 4:45 — $0.99\n3) Desafinado — Antônio Carlos Jobim — Album: Warner 25 Anos — Jazz — 3:05 — $0.99\n4) Corcovado (Quiet Nights Of Quiet Stars) — Antônio Carlos Jobim — Album: Warner 25 Anos — Jazz — 3:26 — $0.99\n5) Dindi — Antônio Carlos Jobim — Album: Warner 25 Anos — Jazz — 4:13 — $0.99\n6) Falando De Amor — Antônio Carlos Jobim — Album: Warner 25 Anos — Jazz — 3:40 — $0.99\n7) OAM's Blues — Aaron Goldberg — Album: Worlds — Jazz — 4:27 — $0.99\n8) Canta, Canta Mais — Antônio Carlos Jobim — Album: Warner 25 Anos — Jazz — 4:32 — $0.99\n9) Outra Vez — Antônio Carlos Jobim — Album: Warner 25 Anos — Jazz — 2:06 — $0.99\n10) Samba De Uma Nota Só (One Note Samba) — Antônio Carlos Jobim — Album: Warner 25 Anos — Jazz — 2:17 — $0.99\n11) Se Todos Fossem Iguais A Você (Instrumental) — Antônio Carlos Jobim — Album: Warner 25 Anos — Jazz — 2:15 — $0.99\n12) Do What Cha Wanna — Billy Cobham — Album: The Best Of Billy Cobham — Jazz — 4:34 — $0.99\n\nTotal duration: about 42 minutes and 10 seconds\nTotal cost: $11.88\n\nNotes and rationale:\n- Starts warm and intimate with Jobim’s beloved tunes, perfect for a ceremony or cocktail hour vibe.\n- Mid-section adds a touch of modern jazz with OAM’s Blues, then keeps the mood relaxed with light instrumentals.\n- Ends with a slightly more upbeat fusion piece to transition into dancing without jarring tempo shifts.\n\nWould you like a shorter (e.g., 8–10 tracks) or longer version, or a mood tweak (more upbeat, more classic vocal jazz, or more instrumental)? I can adjust the list and recalculate duration and cost.", name='suggest_playlist', id='36ef09a0-54a7-4184-bf8e-7c62637a33ce', tool_call_id='call_KlgfL0fAb2r1RJ9n30Sc0FI2'),
#               AIMessage(content='Fantastic news—you’re planning a stylish Paris wedding for 100 guests with a jazz vibe. Here’s how we’re coordinating it all and the best next steps.\n\nWhat we’ve done so far\n- Confirmed state: origin London, destination Paris, guest_count 100, genre Jazz.\n- Flights: I pulled strong direct-London-to-Paris options (great value around 64 EUR and a shortest-flight option at 65 EUR). We’ve got practical guidance on window (late spring to early summer, around 10–16 June 2027) and direct options.\n- Venues: I kicked off venue sourcing in Paris for around 100 guests and pulled a shortlist with price guides and vibe notes.\n- Jazz playlist: I started a lounge-friendly jazz playlist to set the mood for cocktails and dinner, with a plan to tailor by ceremony, cocktail, and dancing.\n\nVenue options we like for 100 guests and a Jazz-friendly vibe\n1) Le Camondo (Paris)\n   - Capacity: ~100\n   - Price: roughly €1,000–€8,400 (range depends on package and date)\n   - Vibe: elegant, historic mansion with intimate spaces\n   - Why it fits: classic Paris ambiance with flexible setup options for a jazz-influenced reception\n\n2) Maison Vivart (via ABC Salles)\n   - Capacity: 2–100 (private event space for 100)\n   - Price: ~€2,200 and up\n   - Vibe: modern chic with a versatile layout\n   - Why it fits: strong balance of price and stylish space for a jazz program and dining\n\n3) La Maison de Charly (Paris)\n   - Capacity: 100\n   - Price: €4,000–€6,000\n   - Vibe: intimate, character-filled venue with a refined feel\n   - Why it fits: great for a romantic, classic Paris wedding with a warm ambiance\n\n4) Hôtel Rochechouart (Paris)\n   - Capacity: 100\n   - Price: from ~€4,000\n   - Vibe: stylish boutique hotel with a party-friendly space\n   - Why it fits: excellent balance of venue, service, and central location\n\n5) The Peninsula Paris\n   - Capacity: up to 100 (ballroom options for ~100)\n   - Price: not publicly listed; premium option\n   - Vibe: ultra-line-styled luxury with top-tier service\n   - Why it fits: world-class luxury if you want a glamorous, high-end experience\n\nNext steps for venues\n- I can pull direct contact details, availability, and formal quotes for your top 2–3 choices.\n- If you’d like, I can arrange site visits or virtual tours and help compare packages (catering, decor, audiovisual, corkage, and any jazz-friendly setup).\n\nFlight plan and guest travel\n- Window: around 10–16 June 2027 is the sweet spot for direct-London-to-Paris options and good weather.\n- Direct routes we can leverage:\n  - London Luton (LTN) → Paris CDG: frequent direct options in this window (roughly €64–€64 range in our notes)\n  - London Southend (SEN) → Paris CDG: direct, ~€65 option\n- How I’ll coordinate:\n  - Work with a travel partner to set up a group block for the main route(s) (LTN→CDG as the primary) and a secondary block if many guests prefer SEN/CDG.\n  - Collect guest arrival/departure preferences (airport, date, times) and assemble a single travel plan with recommended airport transfers.\n  - Provide a simple RSVP-driven travel survey to capture preferred dates and any special needs (allergies, accessibility, seating, etc.).\n- What I need from you to lock this in:\n  - Are you happy with a broad flight window centered around 12–15 June 2027 for most guests?\n  - Do you want me to prioritize LTN→CDG as the main group route and use SEN→CDG as a backup for guests near-Southend?\n  - Any preferred carrier or cabin class? (Economy is fine for most, but we can explore premium economy for VIPs.)\n\nMusic and playlists\n- Current direction: lounge-friendly jazz with a mix of classic bossa nova vibes and smooth instrumentals, suitable for pre-ceremony, cocktail hour, and dinner, with options to amp up for dancing.\n- Suggested setup options:\n  - Option A: Live jazz quartet for ceremony and cocktail hour, DJ for dancing (smooth transition with a curated jazz-DJ hybrid set).\n  - Option B: Jazz trio ...
#  'origin': 'London'}

# %%
print(response["messages"][-1].content)
# Out:
# Fantastic news—you’re planning a stylish Paris wedding for 100 guests with a jazz vibe. Here’s how we’re coordinating it all and the best next steps.
#
# What we’ve done so far
# - Confirmed state: origin London, destination Paris, guest_count 100, genre Jazz.
# - Flights: I pulled strong direct-London-to-Paris options (great value around 64 EUR and a shortest-flight option at 65 EUR). We’ve got practical guidance on window (late spring to early summer, around 10–16 June 2027) and direct options.
# - Venues: I kicked off venue sourcing in Paris for around 100 guests and pulled a shortlist with price guides and vibe notes.
# - Jazz playlist: I started a lounge-friendly jazz playlist to set the mood for cocktails and dinner, with a plan to tailor by ceremony, cocktail, and dancing.
#
# Venue options we like for 100 guests and a Jazz-friendly vibe
# 1) Le Camondo (Paris)
#    - Capacity: ~100
#    - Price: roughly €1,000–€8,400 (range depends on package and date)
#    - Vibe: elegant, historic mansion with intimate spaces
#    - Why it fits: classic Paris ambiance with flexible setup options for a jazz-influenced reception
#
# 2) Maison Vivart (via ABC Salles)
#    - Capacity: 2–100 (private event space for 100)
#    - Price: ~€2,200 and up
#    - Vibe: modern chic with a versatile layout
#    - Why it fits: strong balance of price and stylish space for a jazz program and dining
#
# 3) La Maison de Charly (Paris)
#    - Capacity: 100
#    - Price: €4,000–€6,000
#    - Vibe: intimate, character-filled venue with a refined feel
#    - Why it fits: great for a romantic, classic Paris wedding with a warm ambiance
#
# 4) Hôtel Rochechouart (Paris)
#    - Capacity: 100
#    - Price: from ~€4,000
#    - Vibe: stylish boutique hotel with a party-friendly space
#    - Why it fits: excellent balance of venue, service, and central location
#
# 5) The Peninsula Paris
#    - Capacity: up to 100 (ballroom options for ~100)
#    - Price: not publicly listed; premium option
#    - Vibe: ultra-line-styled luxury with top-tier service
#    - Why it fits: world-class luxury if you want a glamorous, high-end experience
#
# Next steps for venues
# - I can pull direct contact details, availability, and formal quotes for your top 2–3 choices.
# - If you’d like, I can arrange site visits or virtual tours and help compare packages (catering, decor, audiovisual, corkage, and any jazz-friendly setup).
#
# Flight plan and guest travel
# - Window: around 10–16 June 2027 is the sweet spot for direct-London-to-Paris options and good weather.
# - Direct routes we can leverage:
#   - London Luton (LTN) → Paris CDG: frequent direct options in this window (roughly €64–€64 range in our notes)
#   - London Southend (SEN) → Paris CDG: direct, ~€65 option
# - How I’ll coordinate:
#   - Work with a travel partner to set up a group block for the main route(s) (LTN→CDG as the primary) and a secondary block if many guests prefer SEN/CDG.
#   - Collect guest arrival/departure preferences (airport, date, times) and assemble a single travel plan with recommended airport transfers.
#   - Provide a simple RSVP-driven travel survey to capture preferred dates and any special needs (allergies, accessibility, seating, etc.).
# - What I need from you to lock this in:
#   - Are you happy with a broad flight window centered around 12–15 June 2027 for most guests?
#   - Do you want me to prioritize LTN→CDG as the main group route and use SEN→CDG as a backup for guests near-Southend?
#   - Any preferred carrier or cabin class? (Economy is fine for most, but we can explore premium economy for VIPs.)
#
# Music and playlists
# - Current direction: lounge-friendly jazz with a mix of classic bossa nova vibes and smooth instrumentals, suitable for pre-ceremony, cocktail hour, and dinner, with options to amp up for dancing.
# - Suggested setup options:
#   - Option A: Live jazz quartet for ceremony and cocktail hour, DJ for dancing (smooth transition with a curated jazz-DJ hybrid set).
#   - Option B: Jazz trio or quartet for entire evening with a curated playlist for dancing, plus a short live set to kick off dancing.
# - Tailored playlist plan (short preview):
#   - Ceremony/cocktail mood: intimate, instrumental or light vocal jazz (Jobim and similar, with a modern touch)
#   - Dinner: relaxed, sophisticated jazz standards
#   - Dancing: upbeat jazz and light swing/funk to keep energy without feeling too loud
# - I can tailor this to your themes (classic Parisian chic vs. modern-lounge) and then provide a final, day-of schedule with artists or DJs.
#
# Estimated rough budget guidance (to help with planning)
# - Venue (100 guests, mid-range to premium): €4,000–€12,000+ depending on space, date, and packages
# - Catering and beverages for 100 guests (signature menu, drinks): €120–€250 per guest, depending on menu and bar service
# - Music/entertainment: €2,000–€12,000+ depending on live acts vs. DJ, duration, and acoustics
# - Travel/logistics for guests: variable; group blocks can save costs, but individual travel remains a consideration
#
# Questions to finalize and move forward
# - Which 2–3 venues would you like me to pursue more aggressively (Le Camondo, Maison Vivart, La Maison de Charly, Hôtel Rochechouart, The Peninsula)?
# - Do you want me to set up viewings or virtual tours for those venues?
# - Do you want a single main flight route (LTN→CDG) with a backup (SEN→CDG), and to target a group block for roughly how many seats?
# - What is your approximate overall wedding budget (venue, catering, decor, and entertainment)?
# - Do you want a live jazz band for the ceremony and cocktail hour, or a DJ with a curated jazz playlist?
# - Any dietary restrictions, alcohol preferences, or cultural/traditional elements to accommodate?
# - Desired mood and formality level (e.g., ultra-formal black-tie, or contemporary chic with relaxed vibe)?
#
# What I’ll do next (once you confirm)
# - Contact top 2–3 venues for availability and quotes in your preferred date range; prepare a side-by-side comparison with inclusions and add-ons.
# - Lock in flight-block strategy with a travel partner, gather guest preferences, and present a clear travel plan with transfer options.
# - Refine the music plan into a day-of schedule, lock in either a live act or DJ, and deliver a final playlist tailored to ceremony, cocktail, dinner, and dancing.
#
# If you’d like, I can start by narrowing to a top 3 venues based on your vibes (historic Parisian charm vs. modern chic) and create a quick, compare-and-contrast sheet with availability for June 12–15, 2027. Then I’ll pair that with a flight-block proposal and a refined music plan. What would you like your top venue shortlist to be?

# %% [markdown]
# link to trace: https://eu.smith.langchain.com/public/664fca04-fd13-44c7-82cb-14f3dd81e72a/r/019fdc82-6924-7e60-b4d1-43c589cf6787?start_time=2026-08-07T13%3A56%3A01.956980
