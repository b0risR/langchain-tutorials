# %%
from dotenv import load_dotenv
from rich.pretty import pprint as rpprint

load_dotenv()
# Out:
# True

# %% [markdown]
# # 2.4 Wedding Planner
# In this lab you will build a multi-agent wedding planner.
#
# > Note: This lab has been updated since filming to make the agent performance more robust to errors and to limit run time. In particular: 1) added error handling for MCP failures, 2) limited the number of searches. It's worth noting that, where possible, tool errors should be returned to the agent rather than failing so that the agent can adjust its invocation and try again.

# %% [markdown]
# ## Setup Tools

# %%
import asyncio

from mcp.shared.exceptions import McpError
from mcp.types import CallToolResult, TextContent

RETRYABLE_MCP_CODES = {-32603}

class RetryMCPInterceptor:
    """Intercept MCP tool calls: retry transient failures, surface all errors gracefully.

    - Retryable McpError codes (e.g. -32603): retry with exponential backoff.
    - Non-retryable McpError codes (e.g. -32602): return error message immediately.
    - Any other exception (fetch failed, network errors, etc.): retry then return error message.
    """

    def __init__(self, max_retries: int = 3):
        self.max_retries = max_retries

    async def __call__(self, request, handler):
        last_error = None
        for attempt in range(self.max_retries):
            try:
                return await handler(request)
            except McpError as exc:
                last_error = exc
                print(f"[MCP interceptor] {type(exc).__name__} on {request.name} "
                      f"(code {exc.error.code}, attempt {attempt+1}/{self.max_retries}): {exc}")
                if exc.error.code not in RETRYABLE_MCP_CODES:
                    return CallToolResult(
                        content=[TextContent(type="text", text=f"Tool call failed (non-retryable): {exc}")],
                        isError=False,
                    )
            except Exception as exc:
                last_error = exc
                print(f"[MCP interceptor] {type(exc).__name__} on {request.name} "
                      f"(attempt {attempt+1}/{self.max_retries}): {exc}")

            if attempt < self.max_retries - 1:
                await asyncio.sleep(2 ** attempt)

        print(f"[MCP interceptor] all {self.max_retries} retries exhausted for {request.name}")
        return CallToolResult(
            content=[TextContent(type="text", text=f"Tool call failed after {self.max_retries} attempts: {last_error}")],
            isError=False,
        )

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    },
    tool_interceptors=[RetryMCPInterceptor()],
)

tools = await client.get_tools()

# %%
from typing import Any

from langchain.tools import tool
from tavily import TavilyClient
from tavily.errors import (
    BadRequestError,
    ForbiddenError,
    InvalidAPIKeyError,
    MissingAPIKeyError,
    UsageLimitExceededError,
)
from tavily.errors import TimeoutError as TavilyTimeoutError

tavily_client = TavilyClient()

@tool
def web_search(query: str, search_number: int, max_search_number: int) -> dict[str, Any]:
    """Search the web for information. You must track your search count by providing
    search_number (starting at 1) and max_search_number on every call.
    Queries must use only plain text characters. Do not use accented or special characters     
      (e.g., use 'capacite' instead of 'capacité').
    """
    if search_number > max_search_number:
        return {"message": "Search limit reached. Please summarize your findings and provide your final answer."}
    try:
        return tavily_client.search(query)
    except (
        BadRequestError,
        ForbiddenError,
        InvalidAPIKeyError,
        MissingAPIKeyError,
        UsageLimitExceededError,
        TavilyTimeoutError,
        ValueError,
        OSError,
    ) as e:
        return {"error": str(e)}

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

@tool
def query_playlist_db(query: str) -> str:

    """Query the database for playlist information"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error querying database: {e}"

# %% [markdown]
# ## Create State

# %%
from langchain.agents import AgentState


class WeddingState(AgentState):
    origin: str
    destination: str
    guest_count: str
    genre: str

# %% [markdown]
# ## Create Subagents

# %%
from langchain.agents import create_agent

# Travel agent
travel_agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt="""
    You are a travel agent. Search for flights to the desired destination wedding location.
    You are not allowed to ask any more follow up questions, you must find the best flight options based on the following criteria:
    - Price (lowest, economy class)
    - Duration (shortest)
    - Date (time of year which you believe is best for a wedding at this location)
    To make things easy, only look for one ticket, one way.
    You may need to make multiple searches to iteratively find the best options.
    You will be given no extra information, only the origin and destination. It is your job to think critically about the best options.
    If the MCP tool fails, returns malformed output, or does not give you usable flight results, try the tool again.
    Once you have found the best options, let the user know your shortlist of options.
    """
)

# %%
# Venue agent
venue_agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt="""
    You are a venue specialist. Search for venues in the desired location, and with the desired capacity.
    You are not allowed to ask any more follow up questions, you must find the best venue options based on the following criteria:
    - Price (lowest)
    - Capacity (exact match)
    - Reviews (highest)
    You may need to make multiple searches to iteratively find the best options. 
    You have a suggested limit of 12 web searches. Count every web_search call you make.
    After 12 searches, you should stop searching and summarize the best options you have
    found so far.
    """
)

# %%
# Playlist agent
playlist_agent = create_agent(
    model="gpt-5-nano",
    tools=[query_playlist_db],
    system_prompt="""
    You are a playlist specialist. Query the sql database and curate the perfect playlist for a wedding given a genre.
    Once you have your playlist, calculate the total duration and cost of the playlist, each song has an associated price.
    If you run into errors when querying the database, try to fix them by making changes to the query.
    Do not come back empty handed, keep trying to query the db until you find a list of songs.

    This is a SQLite database. Before writing any data queries, first discover the schema.
    """
)

# %% [markdown]
# ## Main Coordinator

# %%
from langchain.messages import HumanMessage, ToolMessage
from langchain.tools import ToolRuntime
from langgraph.types import Command


@tool
async def search_flights(runtime: ToolRuntime) -> str:
    """Travel agent searches for flights to the desired destination wedding location."""
    origin = runtime.state["origin"]
    destination = runtime.state["destination"]
    message = HumanMessage(content=f"Find flights from {origin} to {destination}")
    response = await travel_agent.ainvoke({"messages": [message]})
    return response['messages'][-1].content

@tool
def search_venues(runtime: ToolRuntime) -> str:
    """Venue agent chooses the best venue for the given location and capacity."""
    destination = runtime.state["destination"]
    capacity = runtime.state["guest_count"]
    query = f"Find wedding venues in {destination} for {capacity} guests"
    response = venue_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def suggest_playlist(runtime: ToolRuntime) -> str:
    """Playlist agent curates the perfect playlist for the given genre."""
    genre = runtime.state["genre"]
    query = f"Find {genre} tracks for wedding playlist"
    response = playlist_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def update_state(origin: str, destination: str, guest_count: str, genre: str, runtime: ToolRuntime) -> str:
    """Update the state when you know all of the values: origin, destination, guest_count, genre. 
    This tool must be called alone, without any other tool calls. It must complete and return to make,
    the information available to other tools."""
    return Command(update={
        "origin": origin, 
        "destination": destination, 
        "guest_count": guest_count, 
        "genre": genre, 
        "messages": [ToolMessage("Successfully updated state", tool_call_id=runtime.tool_call_id)]} # type: ignore
        )

# %%
from langchain.agents import create_agent

coordinator = create_agent(
    model="gpt-5-nano",
    tools=[search_flights, search_venues, suggest_playlist, update_state],
    state_schema=WeddingState,
    system_prompt="""
    You are a wedding coordinator. 
    First find all the information you need to update the state. When you have the information, update the state.
    Once that has completed and returned, you can delegate the tasks 
    to your specialists for flights, venues, and playlists.
    Once you have received their answers, coordinate the perfect wedding for me.
    """
)

# %% [markdown]
# ## Test

# %%
message = HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre")

response = await coordinator.ainvoke(
    {
        "messages": [message],
    },
    config={"tags": ["WP"], "recursion_limit": 40},  #tag traces to make them easy to find in Langsmith. Increase number of steps the agent can take to 40.
)

# %%
rpprint(response)
# Out:
# {
# │   'messages': [
# │   │   HumanMessage(
# │   │   │   content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre",
# │   │   │   additional_kwargs={},
# │   │   │   response_metadata={},
# │   │   │   id='13246ecf-b6b9-47df-aa3e-e4ba4c0c720f'
# │   │   ),
# │   │   AIMessage(
# │   │   │   content='',
# │   │   │   additional_kwargs={'refusal': None},
# │   │   │   response_metadata={
# │   │   │   │   'token_usage': {
# │   │   │   │   │   'completion_tokens': 549,
# │   │   │   │   │   'prompt_tokens': 336,
# │   │   │   │   │   'total_tokens': 885,
# │   │   │   │   │   'completion_tokens_details': {
# │   │   │   │   │   │   'accepted_prediction_tokens': 0,
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'reasoning_tokens': 512,
# │   │   │   │   │   │   'rejected_prediction_tokens': 0
# │   │   │   │   │   },
# │   │   │   │   │   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
# │   │   │   │   },
# │   │   │   │   'model_provider': 'openai',
# │   │   │   │   'model_name': 'gpt-5-nano-2025-08-07',
# │   │   │   │   'system_fingerprint': None,
# │   │   │   │   'id': 'chatcmpl-EPvPuOxgLu0kii68VjR8y4hnEnOCk',
# │   │   │   │   'service_tier': 'default',
# │   │   │   │   'finish_reason': 'tool_calls',
# │   │   │   │   'logprobs': None
# │   │   │   },
# │   │   │   id='lc_run--01a0bb3b-400c-76c2-8096-5b517d96bfe3-0',
# │   │   │   tool_calls=[
# │   │   │   │   {
# │   │   │   │   │   'name': 'update_state',
# │   │   │   │   │   'args': {'origin': 'London', 'destination': 'Paris', 'guest_count': '100', 'genre': 'jazz'},
# │   │   │   │   │   'id': 'call_HPFfwB1FW6XurUfB6jkX7zZ9',
# │   │   │   │   │   'type': 'tool_call'
# │   │   │   │   }
# │   │   │   ],
# │   │   │   invalid_tool_calls=[],
# │   │   │   usage_metadata={
# │   │   │   │   'input_tokens': 336,
# │   │   │   │   'output_tokens': 549,
# │   │   │   │   'total_tokens': 885,
# │   │   │   │   'input_token_details': {'audio': 0, 'cache_read': 0},
# │   │   │   │   'output_token_details': {'audio': 0, 'reasoning': 512}
# │   │   │   }
# │   │   ),
# │   │   ToolMessage(
# │   │   │   content='Successfully updated state',
# │   │   │   name='update_state',
# │   │   │   id='8612dbd3-4c36-4eba-92da-98d44ef5dcb8',
# │   │   │   tool_call_id='call_HPFfwB1FW6XurUfB6jkX7zZ9'
# │   │   ),
# │   │   AIMessage(
# │   │   │   content='',
# │   │   │   additional_kwargs={'refusal': None},
# │   │   │   response_metadata={
# │   │   │   │   'token_usage': {
# │   │   │   │   │   'completion_tokens': 14,
# │   │   │   │   │   'prompt_tokens': 381,
# │   │   │   │   │   'total_tokens': 395,
# │   │   │   │   │   'completion_tokens_details': {
# │   │   │   │   │   │   'accepted_prediction_tokens': 0,
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'reasoning_tokens': 0,
# │   │   │   │   │   │   'rejected_prediction_tokens': 0
# │   │   │   │   │   },
# │   │   │   │   │   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
# │   │   │   │   },
# │   │   │   │   'model_provider': 'openai',
# │   │   │   │   'model_name': 'gpt-5-nano-2025-08-07',
# │   │   │   │   'system_fingerprint': None,
# │   │   │   │   'id': 'chatcmpl-EPvPyYgUUDr3NFlibUgNaQMB9nrcE',
# │   │   │   │   'service_tier': 'default',
# │   │   │   │   'finish_reason': 'tool_calls',
# │   │   │   │   'logprobs': None
# │   │   │   },
# │   │   │   id='lc_run--01a0bb3b-52a6-79f0-bc7c-e1e1f16214e6-0',
# │   │   │   tool_calls=[
# │   │   │   │   {
# │   │   │   │   │   'name': 'search_flights',
# │   │   │   │   │   'args': {},
# │   │   │   │   │   'id': 'call_XwY5wLco3QkXmdoTYrtxjlb9',
# │   │   │   │   │   'type': 'tool_call'
# │   │   │   │   }
# │   │   │   ],
# │   │   │   invalid_tool_calls=[],
# │   │   │   usage_metadata={
# │   │   │   │   'input_tokens': 381,
# │   │   │   │   'output_tokens': 14,
# │   │   │   │   'total_tokens': 395,
# │   │   │   │   'input_token_details': {'audio': 0, 'cache_read': 0},
# │   │   │   │   'output_token_details': {'audio': 0, 'reasoning': 0}
# │   │   │   }
# │   │   ),
# │   │   ToolMessage(
# │   │   │   content='Here are the best one-way London → Paris options I found for 01 Oct 2026 (1 adult, economy). All are direct flights except where noted; prices are in EUR and subject to availability.\n\nCheapest option\n- Route: Luton (LTN) → Paris Charles de Gaulle (CDG)\n- Outbound: 01 Oct 2026, 19:30 → 21:50 (≈2h20m)\n- Cabin: Economy\n- Price: 55 EUR\n- Airline: easyJet (U2)\n- Booking: https://kiwi.com/u/wg47rg\n\nOther good budget options (around 70 EUR)\n- Route: Gatwick (LGW) → CDG\n  - Option 1: 01 Oct 2026, 19:10 → 21:30 (≈2h20m)\n  - Price: 70 EUR\n  - Booking: https://kiwi.com/u/m5nyy3\n\n- Route: Gatwick (LGW) → CDG\n  - Option 2: 01 Oct 2026, 18:40 → 21:00 (≈2h20m)\n  - Price: 70 EUR\n  - Booking: https://kiwi.com/u/zzz6z9\n\nOther notable option (slightly higher price for a longer itinerary)\n- Route: Stansted (STN) → Paris Orly (ORY) via one stop (1 stop total)\n  - 07:45 → 16:15 outbound; price 73 EUR\n  - Booking: https://kiwi.com/u/8qfgj3\n\nRecommendation\n- If you want the absolute cheapest: pick the LTN → CDG flight at 55 EUR (LTN 19:30–21:50).\n- If you want the earliest arrival and a very quick trip: LGW → CDG at 18:40–21:00 (70 EUR) is the earliest option among these.\n\nBest time for a Paris wedding\n- Generally lovely in late spring and early fall. If you can pick, consider May–June or September–October for mild weather and beautiful garden ambiance.\n\nFun fact about Paris\n- Paris is nicknamed the City of Light and is famous for landmarks like the Eiffel Tower, Louvre, and charming riverside walks along the Seine.\n\nIf you’d like, I can tailor a second pass with different dates or airports (LHR, LCY, STN, LGW, LTN) to optimize for a particular wedding date window or quicker connections. Have a wonderful trip planning your Paris wedding!',
# │   │   │   name='search_flights',
# │   │   │   id='421e58fe-cc1a-45b6-8d80-bb80858952d2',
# │   │   │   tool_call_id='call_XwY5wLco3QkXmdoTYrtxjlb9'
# │   │   ),
# │   │   AIMessage(
# │   │   │   content='',
# │   │   │   additional_kwargs={'refusal': None},
# │   │   │   response_metadata={
# │   │   │   │   'token_usage': {
# │   │   │   │   │   'completion_tokens': 446,
# │   │   │   │   │   'prompt_tokens': 945,
# │   │   │   │   │   'total_tokens': 1391,
# │   │   │   │   │   'completion_tokens_details': {
# │   │   │   │   │   │   'accepted_prediction_tokens': 0,
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'reasoning_tokens': 384,
# │   │   │   │   │   │   'rejected_prediction_tokens': 0
# │   │   │   │   │   },
# │   │   │   │   │   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
# │   │   │   │   },
# │   │   │   │   'model_provider': 'openai',
# │   │   │   │   'model_name': 'gpt-5-nano-2025-08-07',
# │   │   │   │   'system_fingerprint': None,
# │   │   │   │   'id': 'chatcmpl-EPvQiVjwNDJNdVHNpomONz73SP6Ub',
# │   │   │   │   'service_tier': 'default',
# │   │   │   │   'finish_reason': 'tool_calls',
# │   │   │   │   'logprobs': None
# │   │   │   },
# │   │   │   id='lc_run--01a0bb3c-046a-70b0-90fd-7b6ade679313-0',
# │   │   │   tool_calls=[
# │   │   │   │   {
# │   │   │   │   │   'name': 'search_flights',
# │   │   │   │   │   'args': {},
# │   │   │   │   │   'id': 'call_IJgJ15VAXSKFRA7w3U94aulQ',
# │   │   │   │   │   'type': 'tool_call'
# │   │   │   │   },
# │   │   │   │   {'name': 'search_venues', 'args': {}, 'id': 'call_yCYOyzYOkNpiSCuAl81TN34u', 'type': 'tool_call'},
# │   │   │   │   {
# │   │   │   │   │   'name': 'suggest_playlist',
# │   │   │   │   │   'args': {},
# │   │   │   │   │   'id': 'call_ylp3ohf6ImfPv71yh5pSNa32',
# │   │   │   │   │   'type': 'tool_call'
# │   │   │   │   }
# │   │   │   ],
# │   │   │   invalid_tool_calls=[],
# │   │   │   usage_metadata={
# │   │   │   │   'input_tokens': 945,
# │   │   │   │   'output_tokens': 446,
# │   │   │   │   'total_tokens': 1391,
# │   │   │   │   'input_token_details': {'audio': 0, 'cache_read': 0},
# │   │   │   │   'output_token_details': {'audio': 0, 'reasoning': 384}
# │   │   │   }
# │   │   ),
# │   │   ToolMessage(
# │   │   │   content='Here are the best one-way London to Paris economy flight options I found (for a date I think works well for a wedding in Paris: late spring or early fall). All results are direct flights (0 stops).\n\n1) Cheapest option\n- Route: SEN → CDG\n- Time: 11:10 → 13:20 (local)\n- Duration: about 2h10m\n- Cabin: Economy\n- Price: 51 EUR\n- Airline: easyJet (Flight U24662)\n- Booking: https://kiwi.com/u/kuy6ksk\n\n2) Very affordable option\n- Route: LTN → CDG\n- Time: 19:40 → 22:00\n- Duration: about 2h20m\n- Cabin: Economy\n- Price: 55 EUR\n- Airline: easyJet (Flight U22439)\n- Booking: https://kiwi.com/u/fb6pxu\n\n3) Shortest available (one of the 2h10m direct options)\n- Route: STN → CDG\n- Time: 15:35 → 17:45\n- Duration: about 2h10m\n- Cabin: Economy\n- Price: 73 EUR\n- Airline: easyJet (Flight U24660)\n- Booking: https://kiwi.com/u/6f7d68\n\n4) Direct, solid value (Gatwick option)\n- Route: LGW → CDG\n- Time: 13:10 → 15:30\n- Duration: about 2h20m\n- Cabin: Economy\n- Price: 70 EUR\n- Airline: easyJet (Flight U28411)\n- Booking: https://kiwi.com/u/b3rmwx\n\n5) Direct, later departure (Gatwick option)\n- Route: LGW → CDG\n- Time: 18:15 → 20:35\n- Duration: about 2h20m\n- Cabin: Economy\n- Price: 70 EUR\n- Airline: easyJet (Flight U28407)\n- Booking: https://kiwi.com/u/69x6b9\n\nBest price vs. shortest vs. balanced picks\n- Best price: 51 EUR SEN → CDG (11:10–13:20)\n- Shortest duration options: 11:10–13:20 SEN→CDG and 15:35–17:45 STN→CDG (both ~2h10m)\n- Good balance for a middle departure: 55 EUR LTN→CDG (19:40–22:00) or 70 EUR LGW→CDG (13:10–15:30)\n\nRecommendation\n- If you want the cheapest option, go with SEN → CDG (11:10–13:20) at 51 EUR.\n- If you prefer a very early/evening flight with similar duration, consider STN or LGW direct options around 13:10–17:45 window.\n\nFun fact about Paris to inspire your trip\n- Paris is known as the City of Light and is home to the Louvre, the world’s most visited museum. If you time your visit right, you can pair a magical wedding journey with a memorable museum day.\n\nHave a fantastic trip planning your Paris wedding journey!',
# │   │   │   name='search_flights',
# │   │   │   id='ae847c66-fdb8-42de-a503-249c05942eb6',
# │   │   │   tool_call_id='call_IJgJ15VAXSKFRA7w3U94aulQ'
# │   │   ),
# │   │   ToolMessage(
# │   │   │   content='Here are Paris wedding venues that can host about 100 guests, with the data I found (prioritizing lower price, exact 100-capacity, and solid reviews where shown). I’ve included price cues and the best-known review signals.\n\n- Le Camondo (Paris 8e, near Parc Monceau)\n  - Capacity: 100 guests\n  - Price: roughly €1,000–€8,400 (range shown in listings)\n  - Reviews: Listed on Bridebook with a generally positive profile\n  - Notes: Historic, elegant private-museum vibe; good for a refined, intimate affair\n  - Source: Bridebook listing (capacity and price range)\n\n- Restaurant Maison Blossom (Paris 15e/central area)\n  - Capacity: 100 guests\n  - Price: From €4,000\n  - Reviews: 5.0 rating on Bridebook (7 reviews)\n  - Notes: Modern, stylish setting with in-house catering options\n  - Source: Bridebook listing\n\n- Pavillon Royal (Paris, central area)\n  - Capacity: 100 guests\n  - Price: From €200 per person\n  - Reviews: Listed on Bridebook (high-end venue profile)\n  - Notes: Elegant, versatile banquet spaces; typically used with in-house catering\n  - Source: Bridebook listing\n\n- Le Georges (Georges-Pompidou area, 4th/Marais edge)\n  - Capacity: Up to 100 guests\n  - Price: From €15,000\n  - Reviews: Featured in “10 Confidential Wedding Venues in Paris,” noted for exclusive feel and strong reputation\n  - Notes: Modern, chic with city views; good for a stylish, boutique luxury wedding\n  - Source: Le Georges profile via Le Jo List Studio article\n\n- Ritz Paris (Place Vendôme)\n  - Capacity: Up to 100 guests\n  - Price: on request (high-end venue; explicit price not always published)\n  - Reviews: One of Paris’s most prestigious historic hotels; consistently highly rated\n  - Notes: Classic luxury with iconic interiors; ideal for a lavish Parisian celebration\n  - Source: Ritz Paris event/reception page\n\n- The Peninsula Paris (8th arrondissement)\n  - Capacity: Up to 100 guests for sit-down dinner (various spaces available)\n  - Price: on request (premium-end venue)\n  - Reviews: Top-tier luxury hotel with strong guest reviews\n  - Notes: Elegant ballrooms and full-service planning/catering options\n  - Source: The Peninsula Paris weddings/events page\n\n- Musée Rodin (7e/Paris)\n  - Capacity: ~100 (varies by room/private setup)\n  - Price: on request (varies by package)\n  - Reviews: Frequently cited as a gorgeous, romantic venue with strong reputation\n  - Notes: Museum setting with spectacular sculpture garden backdrop\n  - Source: Bridebook/venue listings (capacity and general reception info)\n\n- Le Crillon / Hôtel de Crillon (Place de la Concorde area)\n  - Capacity: 0-100 depending on the room configuration\n  - Price: on request (luxury-tier)\n  - Reviews: Historic luxury hotel with excellent reviews\n  - Notes: Classic Parisian grandeur; perfect for a timeless ceremony and reception\n  - Source: Paris venue write-ups and venue pages\n\nWhy these fit your criteria\n- Capacity is exactly or firmly within 100 guests for each option above (or clearly listed as up to 100 with suitable banquet configurations).\n- Prices range from lower to very high, giving you a sense of budget options with 100-person capacity. The most clearly budget-friendly option here is Le Camondo (price range around €1k–€8.4k, depending on configuration and date). The Maison Blossom option is a strong mid-range with a clear minimum price (€4k) and a strong review score.\n- Reviews: Maison Blossom has a 5.0 rating on Bridebook (7 reviews), indicating very strong feedback. Other venues are well-known luxury properties with high overall reception in reviews, even if exact numeric ratings aren’t shown in every listing.\n\nNotes\n- Prices often depend on season, exact room configuration, catering packages, and whether you hire in-house catering or external caterers. “Price” here may be a starting point or per-person figure rather than a fixed package.\n- If you want, I can refine further by narrowing to a specific arrondisseme ...
# │   │   │   name='search_venues',
# │   │   │   id='85a48605-c150-469c-b61b-4ae3520dd28b',
# │   │   │   tool_call_id='call_yCYOyzYOkNpiSCuAl81TN34u'
# │   │   ),
# │   │   ToolMessage(
# │   │   │   content="Here’s a wedding-friendly jazz/bossa-nova set pulled from the Jazz tracks in the database. It totals about 57 minutes and 35 seconds, with 15 tracks at $0.99 each (total: $14.85).\n\nCurated tracklist (flow-friendly wedding vibe)\n1) Garota De Ipanema — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 4:45 — Price: $0.99\n2) Corcovado (Quiet Nights Of Quiet Stars) — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 3:26 — Price: $0.99\n3) Desafinado — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 3:05 — Price: $0.99\n4) Dindi — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 4:13 — Price: $0.99\n5) Falando De Amor — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 3:40 — Price: $0.99\n6) OAM's Blues — Aaron Goldberg — Album: Worlds — Duration: 4:27 — Price: $0.99\n7) Amanda — Aisha Duo — Album: Quiet Songs — Duration: 4:06 — Price: $0.99\n8) Despertar — Aisha Duo — Album: Quiet Songs — Duration: 5:07 — Price: $0.99\n9) Canta, Canta Mais — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 4:33 — Price: $0.99\n10) Ligia — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 4:12 — Price: $0.99\n11) Fotografia — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 2:09 — Price: $0.99\n12) O Boto (Bôto) — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 6:07 — Price: $0.99\n13) Outra Vez — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 2:07 — Price: $0.99\n14) Angela — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 2:50 — Price: $0.99\n15) Por Causa De Você — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 2:50 — Price: $0.99\n\nTotals\n- Total duration: 57 minutes 35 seconds\n- Total cost: $14.85\n\nNotes and rationale\n- The mix centers on classic bossa-nova and smooth jazz vocals that are widely interpreted as wedding-appropriate: romantic, non-intrusive, and great for conversation.\n- We start with widely recognizable tunes (Garota De Ipanema, Corcovado) to set a chic mood, then ease into gentle swing and ballads, and finish with a slightly longer, show-piece track (O Boto) to close on a memorable note.\n- If you want more upbeat dance moments, I can swap in more swingy tracks or re-order for a peak later in the evening.\n\nWould you like me to export this as a playlist in your app, or adjust the order to be more ceremony-focused, reception-focused, or more intimate?",
# │   │   │   name='suggest_playlist',
# │   │   │   id='b77cfbca-9dde-4f2a-9d79-8688ce57da81',
# │   │   │   tool_call_id='call_ylp3ohf6ImfPv71yh5pSNa32'
# │   │   ),
# │   │   AIMessage(
# │   │   │   content='Fantastic. I’ve lined up solid options for flights, Paris venues that fit 100 guests, and a jazz-friendly playlist. Here’s what I found and what I recommend next.\n\nFlights (London to Paris for guests)\nTop options (direct, reasonable times, good prices)\n- Option A: SEN → CDG\n  - Time: 11:10 – 13:20\n  - Duration: ~2h10m\n  - Price: 51 EUR\n  - Airline: easyJet (Flight U24662)\n  - Booking: https://kiwi.com/u/kuy6ksk\n  - Pros: Cheapest, good for guests traveling on a mid-morning schedule\n- Option B: LTN → CDG\n  - Time: 19:40 – 22:00\n  - Duration: ~2h20m\n  - Price: 55 EUR\n  - Airline: easyJet (Flight U22439)\n  - Booking: https://kiwi.com/u/fb6pxu\n  - Pros: Evening departure, arrives in Paris late evening\n- Option C: LGW → CDG\n  - Time: 13:10 – 15:30\n  - Duration: ~2h20m\n  - Price: 70 EUR\n  - Airline: easyJet (Flight U28411)\n  - Booking: https://kiwi.com/u/b3rmwx\n  - Pros: Midday option, reasonable price\n- Additional viable option: LGW or STN routes around similar times (prices ~70–73 EUR)\n  - STN → CDG: 15:35 – 17:45, 73 EUR (Flight U24660)\n\nNotes\n- All are direct, typical flight durations ~2h–2h20m.\n- If guests are arriving on different days, we can propose a phased arrival plan with group meet-and-greet transport.\n\nVenues in Paris for 100 guests (price cues and vibe)\nVibe-oriented options with capacity around 100 and typical pricing ranges:\n- Le Camondo (8th arr., near Parc Monceau)\n  - Capacity: ~100\n  - Price: ~€1,000–€8,400 (varies by package/date)\n  - Vibe: Historic, elegant private-museum feel\n  - Best for refined, intimate ambiance\n- Restaurant Maison Blossom (Paris 15e)\n  - Capacity: ~100\n  - Price: From €4,000\n  - Vibe: Modern, stylish with likely in-house catering\n- Pavillon Royal (central Paris)\n  - Capacity: ~100\n  - Price: From €200 per person\n  - Vibe: Elegant banquet spaces, versatile\n- Le Georges (Marais/Opera area)\n  - Capacity: Up to 100\n  - Price: From €15,000\n  - Vibe: Modern, chic with city views\n- Ritz Paris (Place Vendôme)\n  - Capacity: Up to 100\n  - Price: On request (luxury tier)\n  - Vibe: Iconic luxury, classic Parisian grandeur\n- The Peninsula Paris (8th arr.)\n  - Capacity: Up to 100 (banquet)\n  - Price: On request (premium)\n  - Vibe: Ultra-luxury, polished ballrooms\n- Musée Rodin (7e)\n  - Capacity: ~100 (room configurations vary)\n  - Price: On request\n  - Vibe: Romantic, sculpture-garden backdrop\n- Le Crillon / Hôtel de Crillon (Place de la Concorde)\n  - Capacity: 0–100 depending on room\n  - Price: On request\n  - Vibe: Historic luxury, timeless glamour\n\nNotes\n- Prices vary by date, room configuration, catering, and whether you use in-house catering.\n- If you have a vibe (historic stately, modern chic, garden-style, view-focused) or a target arrondissement, I can narrow and pull current quotes.\n\nJazz playlist for the wedding (curated set)\n- Duration: ~57 minutes 35 seconds\n- Tracks: 15\n- Total licensing-ish cost in list: $14.85\n- Vibe: Classic bossa nova and smooth jazz, wedding-friendly, non-intrusive, great for cocktail/reception ambience\n- Sample tracks include: Garota de Ipanema, Corcovado, Desafinado, Dindi, Falando De Amor, plus a few contemporary jazz pieces\n\nWould you like me to export this playlist to Spotify or Apple Music, or tailor the track order for ceremony vs reception (e.g., more classical jazz for ceremony, upbeat swing for later reception)?\n\nNext steps and quick questions\n- Date window: Do you have a target wedding date or month? Any flexibility?\n- Departure options: Should I prioritize a single London airport (e.g., LHR/LGW) or keep multiple options open?\n- Budget guidance: Any budget range for venue (overall), catering, and venue hire?\n- Vibe preferences for the venue: historic mansion, museum, modern chic, luxury hotel ballrooms, or garden setting?\n- In-house catering vs external caterers: Any preferences?\n- Guest logistics: Would you like me to plan a group itinerary (one or tw ...
# │   │   │   additional_kwargs={'refusal': None},
# │   │   │   response_metadata={
# │   │   │   │   'token_usage': {
# │   │   │   │   │   'completion_tokens': 3013,
# │   │   │   │   │   'prompt_tokens': 3490,
# │   │   │   │   │   'total_tokens': 6503,
# │   │   │   │   │   'completion_tokens_details': {
# │   │   │   │   │   │   'accepted_prediction_tokens': 0,
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'reasoning_tokens': 1792,
# │   │   │   │   │   │   'rejected_prediction_tokens': 0
# │   │   │   │   │   },
# │   │   │   │   │   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
# │   │   │   │   },
# │   │   │   │   'model_provider': 'openai',
# │   │   │   │   'model_name': 'gpt-5-nano-2025-08-07',
# │   │   │   │   'system_fingerprint': None,
# │   │   │   │   'id': 'chatcmpl-EPvRkakY4KInc30oTPCz7Ajf9wWkJ',
# │   │   │   │   'service_tier': 'default',
# │   │   │   │   'finish_reason': 'stop',
# │   │   │   │   'logprobs': None
# │   │   │   },
# │   │   │   id='lc_run--01a0bb3c-fd86-7d41-96a6-deefc37ec48f-0',
# │   │   │   tool_calls=[],
# │   │   │   invalid_tool_calls=[],
# │   │   │   usage_metadata={
# │   │   │   │   'input_tokens': 3490,
# │   │   │   │   'output_tokens': 3013,
# │   │   │   │   'total_tokens': 6503,
# │   │   │   │   'input_token_details': {'audio': 0, 'cache_read': 0},
# │   │   │   │   'output_token_details': {'audio': 0, 'reasoning': 1792}
# │   │   │   }
# │   │   )
# │   ],
# │   'origin': 'London',
# │   'destination': 'Paris',
# │   'guest_count': '100',
# │   'genre': 'jazz'
# }

# %%
print(response["messages"][-1].content)
# Out:
# Fantastic. I’ve lined up solid options for flights, Paris venues that fit 100 guests, and a jazz-friendly playlist. Here’s what I found and what I recommend next.
#
# Flights (London to Paris for guests)
# Top options (direct, reasonable times, good prices)
# - Option A: SEN → CDG
#   - Time: 11:10 – 13:20
#   - Duration: ~2h10m
#   - Price: 51 EUR
#   - Airline: easyJet (Flight U24662)
#   - Booking: https://kiwi.com/u/kuy6ksk
#   - Pros: Cheapest, good for guests traveling on a mid-morning schedule
# - Option B: LTN → CDG
#   - Time: 19:40 – 22:00
#   - Duration: ~2h20m
#   - Price: 55 EUR
#   - Airline: easyJet (Flight U22439)
#   - Booking: https://kiwi.com/u/fb6pxu
#   - Pros: Evening departure, arrives in Paris late evening
# - Option C: LGW → CDG
#   - Time: 13:10 – 15:30
#   - Duration: ~2h20m
#   - Price: 70 EUR
#   - Airline: easyJet (Flight U28411)
#   - Booking: https://kiwi.com/u/b3rmwx
#   - Pros: Midday option, reasonable price
# - Additional viable option: LGW or STN routes around similar times (prices ~70–73 EUR)
#   - STN → CDG: 15:35 – 17:45, 73 EUR (Flight U24660)
#
# Notes
# - All are direct, typical flight durations ~2h–2h20m.
# - If guests are arriving on different days, we can propose a phased arrival plan with group meet-and-greet transport.
#
# Venues in Paris for 100 guests (price cues and vibe)
# Vibe-oriented options with capacity around 100 and typical pricing ranges:
# - Le Camondo (8th arr., near Parc Monceau)
#   - Capacity: ~100
#   - Price: ~€1,000–€8,400 (varies by package/date)
#   - Vibe: Historic, elegant private-museum feel
#   - Best for refined, intimate ambiance
# - Restaurant Maison Blossom (Paris 15e)
#   - Capacity: ~100
#   - Price: From €4,000
#   - Vibe: Modern, stylish with likely in-house catering
# - Pavillon Royal (central Paris)
#   - Capacity: ~100
#   - Price: From €200 per person
#   - Vibe: Elegant banquet spaces, versatile
# - Le Georges (Marais/Opera area)
#   - Capacity: Up to 100
#   - Price: From €15,000
#   - Vibe: Modern, chic with city views
# - Ritz Paris (Place Vendôme)
#   - Capacity: Up to 100
#   - Price: On request (luxury tier)
#   - Vibe: Iconic luxury, classic Parisian grandeur
# - The Peninsula Paris (8th arr.)
#   - Capacity: Up to 100 (banquet)
#   - Price: On request (premium)
#   - Vibe: Ultra-luxury, polished ballrooms
# - Musée Rodin (7e)
#   - Capacity: ~100 (room configurations vary)
#   - Price: On request
#   - Vibe: Romantic, sculpture-garden backdrop
# - Le Crillon / Hôtel de Crillon (Place de la Concorde)
#   - Capacity: 0–100 depending on room
#   - Price: On request
#   - Vibe: Historic luxury, timeless glamour
#
# Notes
# - Prices vary by date, room configuration, catering, and whether you use in-house catering.
# - If you have a vibe (historic stately, modern chic, garden-style, view-focused) or a target arrondissement, I can narrow and pull current quotes.
#
# Jazz playlist for the wedding (curated set)
# - Duration: ~57 minutes 35 seconds
# - Tracks: 15
# - Total licensing-ish cost in list: $14.85
# - Vibe: Classic bossa nova and smooth jazz, wedding-friendly, non-intrusive, great for cocktail/reception ambience
# - Sample tracks include: Garota de Ipanema, Corcovado, Desafinado, Dindi, Falando De Amor, plus a few contemporary jazz pieces
#
# Would you like me to export this playlist to Spotify or Apple Music, or tailor the track order for ceremony vs reception (e.g., more classical jazz for ceremony, upbeat swing for later reception)?
#
# Next steps and quick questions
# - Date window: Do you have a target wedding date or month? Any flexibility?
# - Departure options: Should I prioritize a single London airport (e.g., LHR/LGW) or keep multiple options open?
# - Budget guidance: Any budget range for venue (overall), catering, and venue hire?
# - Vibe preferences for the venue: historic mansion, museum, modern chic, luxury hotel ballrooms, or garden setting?
# - In-house catering vs external caterers: Any preferences?
# - Guest logistics: Would you like me to plan a group itinerary (one or two flight blocks, transfer options, welcome drinks, etc.)?
#
# If you’re happy with these directions, I can:
# - Hold or request quotes from the top 2–3 flight options for your preferred date.
# - Reach out to the top 3–4 venues to check availability, packages, and exact capacity details for 100 guests.
# - Prepare a formal, shareable playlist file and confirm export to your streaming service of choice.
#
# Tell me which flight option(s), venue vibe, and any date window you’d like me to start with, and I’ll coordinate the next steps with the specialists.

# %% [markdown]
# link to trace: https://eu.smith.langchain.com/public/664fca04-fd13-44c7-82cb-14f3dd81e72a/r/019fdc82-6924-7e60-b4d1-43c589cf6787?start_time=2026-08-07T13%3A56%3A01.956980
