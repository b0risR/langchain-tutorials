# %%
from dotenv import load_dotenv
from rich.pretty import pprint as rpprint

load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

# %%
from langchain.tools import tool


@tool
def sql_query(query: str) -> str:

    """Obtain information from the database using SQL queries"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error: {e}"

# %%
sql_query.invoke("SELECT * FROM Artist LIMIT 10")
# Out:
# "[(1, 'AC/DC'), (2, 'Accept'), (3, 'Aerosmith'), (4, 'Alanis Morissette'), (5, 'Alice In Chains'), (6, 'Antônio Carlos Jobim'), (7, 'Apocalyptica'), (8, 'Audioslave'), (9, 'BackBeat'), (10, 'Billy Cobham')]"

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=[sql_query]
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Who is the most popular artist beginning with 'S' in this database?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
rpprint(response)
# Out:
# {
# │   'messages': [
# │   │   HumanMessage(
# │   │   │   content="Who is the most popular artist beginning with 'S' in this database?",
# │   │   │   additional_kwargs={},
# │   │   │   response_metadata={},
# │   │   │   id='b511ded6-1d88-43a4-ae1d-e8caa436101d'
# │   │   ),
# │   │   AIMessage(
# │   │   │   content='',
# │   │   │   additional_kwargs={'refusal': None},
# │   │   │   response_metadata={
# │   │   │   │   'token_usage': {
# │   │   │   │   │   'completion_tokens': 557,
# │   │   │   │   │   'prompt_tokens': 142,
# │   │   │   │   │   'total_tokens': 699,
# │   │   │   │   │   'completion_tokens_details': {
# │   │   │   │   │   │   'accepted_prediction_tokens': 0,
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'reasoning_tokens': 512,
# │   │   │   │   │   │   'rejected_prediction_tokens': 0
# │   │   │   │   │   },
# │   │   │   │   │   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
# │   │   │   │   },
# │   │   │   │   'model_provider': 'openai',
# │   │   │   │   'model_name': 'gpt-5-nano-2025-08-07',
# │   │   │   │   'system_fingerprint': None,
# │   │   │   │   'id': 'chatcmpl-EQfKC5a1N3M55MATb0a7661beOgu0',
# │   │   │   │   'service_tier': 'default',
# │   │   │   │   'finish_reason': 'tool_calls',
# │   │   │   │   'logprobs': None
# │   │   │   },
# │   │   │   id='lc_run--01a0c5bf-f365-71c1-9028-828c038ca4e1-0',
# │   │   │   tool_calls=[
# │   │   │   │   {
# │   │   │   │   │   'name': 'sql_query',
# │   │   │   │   │   'args': {
# │   │   │   │   │   │   'query': "SELECT name, popularity FROM artists WHERE name LIKE 'S%' ORDER BY popularity DESC, name ASC LIMIT 1;"
# │   │   │   │   │   },
# │   │   │   │   │   'id': 'call_wRfQoTQLK40uG85GlGzMYNIR',
# │   │   │   │   │   'type': 'tool_call'
# │   │   │   │   }
# │   │   │   ],
# │   │   │   invalid_tool_calls=[],
# │   │   │   usage_metadata={
# │   │   │   │   'input_tokens': 142,
# │   │   │   │   'output_tokens': 557,
# │   │   │   │   'total_tokens': 699,
# │   │   │   │   'input_token_details': {'audio': 0, 'cache_read': 0},
# │   │   │   │   'output_token_details': {'audio': 0, 'reasoning': 512}
# │   │   │   }
# │   │   ),
# │   │   ToolMessage(
# │   │   │   content="Error: (sqlite3.OperationalError) no such table: artists\n[SQL: SELECT name, popularity FROM artists WHERE name LIKE 'S%' ORDER BY popularity DESC, name ASC LIMIT 1;]\n(Background on this error at: https://sqlalche.me/e/20/e3q8)",
# │   │   │   name='sql_query',
# │   │   │   id='8b212a0b-3da3-4730-86c5-5e4fa6a63932',
# │   │   │   tool_call_id='call_wRfQoTQLK40uG85GlGzMYNIR'
# │   │   ),
# │   │   AIMessage(
# │   │   │   content='',
# │   │   │   additional_kwargs={'refusal': None},
# │   │   │   response_metadata={
# │   │   │   │   'token_usage': {
# │   │   │   │   │   'completion_tokens': 224,
# │   │   │   │   │   'prompt_tokens': 255,
# │   │   │   │   │   'total_tokens': 479,
# │   │   │   │   │   'completion_tokens_details': {
# │   │   │   │   │   │   'accepted_prediction_tokens': 0,
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'reasoning_tokens': 192,
# │   │   │   │   │   │   'rejected_prediction_tokens': 0
# │   │   │   │   │   },
# │   │   │   │   │   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
# │   │   │   │   },
# │   │   │   │   'model_provider': 'openai',
# │   │   │   │   'model_name': 'gpt-5-nano-2025-08-07',
# │   │   │   │   'system_fingerprint': None,
# │   │   │   │   'id': 'chatcmpl-EQfKHPfqxozwk8ENdnK7BGhhsp95p',
# │   │   │   │   'service_tier': 'default',
# │   │   │   │   'finish_reason': 'tool_calls',
# │   │   │   │   'logprobs': None
# │   │   │   },
# │   │   │   id='lc_run--01a0c5c0-0f29-70a2-9e52-01ef91f10a04-0',
# │   │   │   tool_calls=[
# │   │   │   │   {
# │   │   │   │   │   'name': 'sql_query',
# │   │   │   │   │   'args': {'query': "SELECT name FROM sqlite_master WHERE type='table';"},
# │   │   │   │   │   'id': 'call_GXY1I0EPV7XzMnuukTa5Gny3',
# │   │   │   │   │   'type': 'tool_call'
# │   │   │   │   }
# │   │   │   ],
# │   │   │   invalid_tool_calls=[],
# │   │   │   usage_metadata={
# │   │   │   │   'input_tokens': 255,
# │   │   │   │   'output_tokens': 224,
# │   │   │   │   'total_tokens': 479,
# │   │   │   │   'input_token_details': {'audio': 0, 'cache_read': 0},
# │   │   │   │   'output_token_details': {'audio': 0, 'reasoning': 192}
# │   │   │   }
# │   │   ),
# │   │   ToolMessage(
# │   │   │   content="[('Album',), ('Artist',), ('Customer',), ('Employee',), ('Genre',), ('Invoice',), ('InvoiceLine',), ('MediaType',), ('Playlist',), ('PlaylistTrack',), ('Track',)]",
# │   │   │   name='sql_query',
# │   │   │   id='2ff52546-1202-44e9-ad11-363184b71752',
# │   │   │   tool_call_id='call_GXY1I0EPV7XzMnuukTa5Gny3'
# │   │   ),
# │   │   AIMessage(
# │   │   │   content='',
# │   │   │   additional_kwargs={'refusal': None},
# │   │   │   response_metadata={
# │   │   │   │   'token_usage': {
# │   │   │   │   │   'completion_tokens': 39,
# │   │   │   │   │   'prompt_tokens': 340,
# │   │   │   │   │   'total_tokens': 379,
# │   │   │   │   │   'completion_tokens_details': {
# │   │   │   │   │   │   'accepted_prediction_tokens': 0,
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'reasoning_tokens': 0,
# │   │   │   │   │   │   'rejected_prediction_tokens': 0
# │   │   │   │   │   },
# │   │   │   │   │   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
# │   │   │   │   },
# │   │   │   │   'model_provider': 'openai',
# │   │   │   │   'model_name': 'gpt-5-nano-2025-08-07',
# │   │   │   │   'system_fingerprint': None,
# │   │   │   │   'id': 'chatcmpl-EQfKKHSzgzKXBt05TCSpPCXybti5Q',
# │   │   │   │   'service_tier': 'default',
# │   │   │   │   'finish_reason': 'tool_calls',
# │   │   │   │   'logprobs': None
# │   │   │   },
# │   │   │   id='lc_run--01a0c5c0-1949-7132-b700-52bc1feb5709-0',
# │   │   │   tool_calls=[
# │   │   │   │   {
# │   │   │   │   │   'name': 'sql_query',
# │   │   │   │   │   'args': {
# │   │   │   │   │   │   'query': "SELECT name, popularity FROM Artist WHERE name LIKE 'S%' ORDER BY popularity DESC, name ASC LIMIT 1;"
# │   │   │   │   │   },
# │   │   │   │   │   'id': 'call_xLWZV0G2oppnNZpCbEh0TVfb',
# │   │   │   │   │   'type': 'tool_call'
# │   │   │   │   }
# │   │   │   ],
# │   │   │   invalid_tool_calls=[],
# │   │   │   usage_metadata={
# │   │   │   │   'input_tokens': 340,
# │   │   │   │   'output_tokens': 39,
# │   │   │   │   'total_tokens': 379,
# │   │   │   │   'input_token_details': {'audio': 0, 'cache_read': 0},
# │   │   │   │   'output_token_details': {'audio': 0, 'reasoning': 0}
# │   │   │   }
# │   │   ),
# │   │   ToolMessage(
# │   │   │   content="Error: (sqlite3.OperationalError) no such column: popularity\n[SQL: SELECT name, popularity FROM Artist WHERE name LIKE 'S%' ORDER BY popularity DESC, name ASC LIMIT 1;]\n(Background on this error at: https://sqlalche.me/e/20/e3q8)",
# │   │   │   name='sql_query',
# │   │   │   id='0a2cd772-ec71-437e-95d2-dbe4b3e02445',
# │   │   │   tool_call_id='call_xLWZV0G2oppnNZpCbEh0TVfb'
# │   │   ),
# │   │   AIMessage(
# │   │   │   content='',
# │   │   │   additional_kwargs={'refusal': None},
# │   │   │   response_metadata={
# │   │   │   │   'token_usage': {
# │   │   │   │   │   'completion_tokens': 23,
# │   │   │   │   │   'prompt_tokens': 453,
# │   │   │   │   │   'total_tokens': 476,
# │   │   │   │   │   'completion_tokens_details': {
# │   │   │   │   │   │   'accepted_prediction_tokens': 0,
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'reasoning_tokens': 0,
# │   │   │   │   │   │   'rejected_prediction_tokens': 0
# │   │   │   │   │   },
# │   │   │   │   │   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
# │   │   │   │   },
# │   │   │   │   'model_provider': 'openai',
# │   │   │   │   'model_name': 'gpt-5-nano-2025-08-07',
# │   │   │   │   'system_fingerprint': None,
# │   │   │   │   'id': 'chatcmpl-EQfKMCZffHnUhl5ibXoUEzaUSz3Mx',
# │   │   │   │   'service_tier': 'default',
# │   │   │   │   'finish_reason': 'tool_calls',
# │   │   │   │   'logprobs': None
# │   │   │   },
# │   │   │   id='lc_run--01a0c5c0-1d9f-7e40-960f-b1a77800316b-0',
# │   │   │   tool_calls=[
# │   │   │   │   {
# │   │   │   │   │   'name': 'sql_query',
# │   │   │   │   │   'args': {'query': 'PRAGMA table_info(Artist);'},
# │   │   │   │   │   'id': 'call_UpvTeM5EqD2GocincmcIRPGH',
# │   │   │   │   │   'type': 'tool_call'
# │   │   │   │   }
# │   │   │   ],
# │   │   │   invalid_tool_calls=[],
# │   │   │   usage_metadata={
# │   │   │   │   'input_tokens': 453,
# │   │   │   │   'output_tokens': 23,
# │   │   │   │   'total_tokens': 476,
# │   │   │   │   'input_token_details': {'audio': 0, 'cache_read': 0},
# │   │   │   │   'output_token_details': {'audio': 0, 'reasoning': 0}
# │   │   │   }
# │   │   ),
# │   │   ToolMessage(
# │   │   │   content="[(0, 'ArtistId', 'INTEGER', 1, None, 1), (1, 'Name', 'NVARCHAR(120)', 0, None, 0)]",
# │   │   │   name='sql_query',
# │   │   │   id='ecece810-a748-4033-b951-8664593b8573',
# │   │   │   tool_call_id='call_UpvTeM5EqD2GocincmcIRPGH'
# │   │   ),
# │   │   AIMessage(
# │   │   │   content='',
# │   │   │   additional_kwargs={'refusal': None},
# │   │   │   response_metadata={
# │   │   │   │   'token_usage': {
# │   │   │   │   │   'completion_tokens': 663,
# │   │   │   │   │   'prompt_tokens': 525,
# │   │   │   │   │   'total_tokens': 1188,
# │   │   │   │   │   'completion_tokens_details': {
# │   │   │   │   │   │   'accepted_prediction_tokens': 0,
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'reasoning_tokens': 576,
# │   │   │   │   │   │   'rejected_prediction_tokens': 0
# │   │   │   │   │   },
# │   │   │   │   │   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
# │   │   │   │   },
# │   │   │   │   'model_provider': 'openai',
# │   │   │   │   'model_name': 'gpt-5-nano-2025-08-07',
# │   │   │   │   'system_fingerprint': None,
# │   │   │   │   'id': 'chatcmpl-EQfKN141woHq4hYGmE91AAd7pQSZn',
# │   │   │   │   'service_tier': 'default',
# │   │   │   │   'finish_reason': 'tool_calls',
# │   │   │   │   'logprobs': None
# │   │   │   },
# │   │   │   id='lc_run--01a0c5c0-241f-7302-b055-374a0b92e58a-0',
# │   │   │   tool_calls=[
# │   │   │   │   {
# │   │   │   │   │   'name': 'sql_query',
# │   │   │   │   │   'args': {
# │   │   │   │   │   │   'query': "SELECT a.Name, COUNT(t.TrackId) AS TrackCount FROM Artist a JOIN Album al ON al.ArtistId = a.ArtistId JOIN Track t ON t.AlbumId = al.AlbumId WHERE a.Name LIKE 'S%' GROUP BY a.Name ORDER BY TrackCount DESC, a.Name ASC LIMIT 1;"
# │   │   │   │   │   },
# │   │   │   │   │   'id': 'call_MtoaJkCZNnsvSx7adROf0FYU',
# │   │   │   │   │   'type': 'tool_call'
# │   │   │   │   }
# │   │   │   ],
# │   │   │   invalid_tool_calls=[],
# │   │   │   usage_metadata={
# │   │   │   │   'input_tokens': 525,
# │   │   │   │   'output_tokens': 663,
# │   │   │   │   'total_tokens': 1188,
# │   │   │   │   'input_token_details': {'audio': 0, 'cache_read': 0},
# │   │   │   │   'output_token_details': {'audio': 0, 'reasoning': 576}
# │   │   │   }
# │   │   ),
# │   │   ToolMessage(
# │   │   │   content="[('Smashing Pumpkins', 34)]",
# │   │   │   name='sql_query',
# │   │   │   id='be74b152-9ff2-4f89-a1e5-434bf01de67d',
# │   │   │   tool_call_id='call_MtoaJkCZNnsvSx7adROf0FYU'
# │   │   ),
# │   │   AIMessage(
# │   │   │   content='Smashing Pumpkins.\n\nIn this database, I used the number of tracks by the artist as a stand-in for popularity. Smashing Pumpkins has 34 tracks, the most among artists whose names start with S. If you have a different popularity metric in mind (e.g., albums sold, total album count), I can adjust the query.',
# │   │   │   additional_kwargs={'refusal': None},
# │   │   │   response_metadata={
# │   │   │   │   'token_usage': {
# │   │   │   │   │   'completion_tokens': 463,
# │   │   │   │   │   'prompt_tokens': 627,
# │   │   │   │   │   'total_tokens': 1090,
# │   │   │   │   │   'completion_tokens_details': {
# │   │   │   │   │   │   'accepted_prediction_tokens': 0,
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'reasoning_tokens': 384,
# │   │   │   │   │   │   'rejected_prediction_tokens': 0
# │   │   │   │   │   },
# │   │   │   │   │   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
# │   │   │   │   },
# │   │   │   │   'model_provider': 'openai',
# │   │   │   │   'model_name': 'gpt-5-nano-2025-08-07',
# │   │   │   │   'system_fingerprint': None,
# │   │   │   │   'id': 'chatcmpl-EQfKV74LDCpsm7ASe16vxzyD8fkOO',
# │   │   │   │   'service_tier': 'default',
# │   │   │   │   'finish_reason': 'stop',
# │   │   │   │   'logprobs': None
# │   │   │   },
# │   │   │   id='lc_run--01a0c5c0-465e-71f1-86cd-9eee9df4dc89-0',
# │   │   │   tool_calls=[],
# │   │   │   invalid_tool_calls=[],
# │   │   │   usage_metadata={
# │   │   │   │   'input_tokens': 627,
# │   │   │   │   'output_tokens': 463,
# │   │   │   │   'total_tokens': 1090,
# │   │   │   │   'input_token_details': {'audio': 0, 'cache_read': 0},
# │   │   │   │   'output_token_details': {'audio': 0, 'reasoning': 384}
# │   │   │   }
# │   │   )
# │   ]
# }

# %%
print(response["messages"][-1].content)
# Out:
# Smashing Pumpkins.
#
# In this database, I used the number of tracks by the artist as a stand-in for popularity. Smashing Pumpkins has 34 tracks, the most among artists whose names start with S. If you have a different popularity metric in mind (e.g., albums sold, total album count), I can adjust the query.

# %%
@tool
def sql_query(query: str) -> str:
    """Tool for query all the info related to artists and music.
    Start using SQL to obtain the database tables.
    Next, use SQL to obtain the tables columns.
    Finally, get the needed information using the tables and columns info."""
    try:
        return db.run(query)
    except Exception as e:
        return f"Error: {e}"

# %%
question = HumanMessage(content="Who is the most popular artist beginning with 'S' in this database?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
rpprint(response)
# Out:
# {
# │   'messages': [
# │   │   HumanMessage(
# │   │   │   content="Who is the most popular artist beginning with 'S' in this database?",
# │   │   │   additional_kwargs={},
# │   │   │   response_metadata={},
# │   │   │   id='b1cd0663-ada8-44f9-b876-8469850dbaaa'
# │   │   ),
# │   │   AIMessage(
# │   │   │   content='',
# │   │   │   additional_kwargs={'refusal': None},
# │   │   │   response_metadata={
# │   │   │   │   'token_usage': {
# │   │   │   │   │   'completion_tokens': 737,
# │   │   │   │   │   'prompt_tokens': 142,
# │   │   │   │   │   'total_tokens': 879,
# │   │   │   │   │   'completion_tokens_details': {
# │   │   │   │   │   │   'accepted_prediction_tokens': 0,
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'reasoning_tokens': 640,
# │   │   │   │   │   │   'rejected_prediction_tokens': 0
# │   │   │   │   │   },
# │   │   │   │   │   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
# │   │   │   │   },
# │   │   │   │   'model_provider': 'openai',
# │   │   │   │   'model_name': 'gpt-5-nano-2025-08-07',
# │   │   │   │   'system_fingerprint': None,
# │   │   │   │   'id': 'chatcmpl-EQff3l7zNWyOs6PCgsdTYwTi5tLXW',
# │   │   │   │   'service_tier': 'default',
# │   │   │   │   'finish_reason': 'tool_calls',
# │   │   │   │   'logprobs': None
# │   │   │   },
# │   │   │   id='lc_run--01a0c5d3-b421-75c1-8f6a-140837a776d9-0',
# │   │   │   tool_calls=[
# │   │   │   │   {
# │   │   │   │   │   'name': 'sql_query',
# │   │   │   │   │   'args': {
# │   │   │   │   │   │   'query': "SELECT name, popularity FROM artists WHERE name LIKE 'S%' ORDER BY popularity DESC LIMIT 1;"
# │   │   │   │   │   },
# │   │   │   │   │   'id': 'call_X8lFn2OG1SjFxhJL3bRAry1X',
# │   │   │   │   │   'type': 'tool_call'
# │   │   │   │   },
# │   │   │   │   {
# │   │   │   │   │   'name': 'sql_query',
# │   │   │   │   │   'args': {
# │   │   │   │   │   │   'query': "SELECT artist_name, artist_popularity FROM artists WHERE artist_name LIKE 'S%' ORDER BY artist_popularity DESC LIMIT 1;"
# │   │   │   │   │   },
# │   │   │   │   │   'id': 'call_CtTK3845CikduT01tykBx2I9',
# │   │   │   │   │   'type': 'tool_call'
# │   │   │   │   }
# │   │   │   ],
# │   │   │   invalid_tool_calls=[],
# │   │   │   usage_metadata={
# │   │   │   │   'input_tokens': 142,
# │   │   │   │   'output_tokens': 737,
# │   │   │   │   'total_tokens': 879,
# │   │   │   │   'input_token_details': {'audio': 0, 'cache_read': 0},
# │   │   │   │   'output_token_details': {'audio': 0, 'reasoning': 640}
# │   │   │   }
# │   │   ),
# │   │   ToolMessage(
# │   │   │   content="Error: (sqlite3.OperationalError) no such table: artists\n[SQL: SELECT name, popularity FROM artists WHERE name LIKE 'S%' ORDER BY popularity DESC LIMIT 1;]\n(Background on this error at: https://sqlalche.me/e/20/e3q8)",
# │   │   │   name='sql_query',
# │   │   │   id='41b2fe4a-fe0c-4d32-a992-2be961ea7abc',
# │   │   │   tool_call_id='call_X8lFn2OG1SjFxhJL3bRAry1X'
# │   │   ),
# │   │   ToolMessage(
# │   │   │   content="Error: (sqlite3.OperationalError) no such table: artists\n[SQL: SELECT artist_name, artist_popularity FROM artists WHERE artist_name LIKE 'S%' ORDER BY artist_popularity DESC LIMIT 1;]\n(Background on this error at: https://sqlalche.me/e/20/e3q8)",
# │   │   │   name='sql_query',
# │   │   │   id='85871c3a-4a86-4f84-a944-c295e275c5bf',
# │   │   │   tool_call_id='call_CtTK3845CikduT01tykBx2I9'
# │   │   ),
# │   │   AIMessage(
# │   │   │   content='',
# │   │   │   additional_kwargs={'refusal': None},
# │   │   │   response_metadata={
# │   │   │   │   'token_usage': {
# │   │   │   │   │   'completion_tokens': 416,
# │   │   │   │   │   'prompt_tokens': 377,
# │   │   │   │   │   'total_tokens': 793,
# │   │   │   │   │   'completion_tokens_details': {
# │   │   │   │   │   │   'accepted_prediction_tokens': 0,
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'reasoning_tokens': 384,
# │   │   │   │   │   │   'rejected_prediction_tokens': 0
# │   │   │   │   │   },
# │   │   │   │   │   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
# │   │   │   │   },
# │   │   │   │   'model_provider': 'openai',
# │   │   │   │   'model_name': 'gpt-5-nano-2025-08-07',
# │   │   │   │   'system_fingerprint': None,
# │   │   │   │   'id': 'chatcmpl-EQff9mSkANUwNMoySNPLp0F1wX0sE',
# │   │   │   │   'service_tier': 'default',
# │   │   │   │   'finish_reason': 'tool_calls',
# │   │   │   │   'logprobs': None
# │   │   │   },
# │   │   │   id='lc_run--01a0c5d3-cb40-77e3-b7c8-47102c4521eb-0',
# │   │   │   tool_calls=[
# │   │   │   │   {
# │   │   │   │   │   'name': 'sql_query',
# │   │   │   │   │   'args': {'query': "SELECT name FROM sqlite_master WHERE type='table';"},
# │   │   │   │   │   'id': 'call_GYnElzerOtRAEaGIilk2DwD6',
# │   │   │   │   │   'type': 'tool_call'
# │   │   │   │   }
# │   │   │   ],
# │   │   │   invalid_tool_calls=[],
# │   │   │   usage_metadata={
# │   │   │   │   'input_tokens': 377,
# │   │   │   │   'output_tokens': 416,
# │   │   │   │   'total_tokens': 793,
# │   │   │   │   'input_token_details': {'audio': 0, 'cache_read': 0},
# │   │   │   │   'output_token_details': {'audio': 0, 'reasoning': 384}
# │   │   │   }
# │   │   ),
# │   │   ToolMessage(
# │   │   │   content="[('Album',), ('Artist',), ('Customer',), ('Employee',), ('Genre',), ('Invoice',), ('InvoiceLine',), ('MediaType',), ('Playlist',), ('PlaylistTrack',), ('Track',)]",
# │   │   │   name='sql_query',
# │   │   │   id='7824d67d-2e89-4bf0-bd9a-3ba53e8dbed5',
# │   │   │   tool_call_id='call_GYnElzerOtRAEaGIilk2DwD6'
# │   │   ),
# │   │   AIMessage(
# │   │   │   content='',
# │   │   │   additional_kwargs={'refusal': None},
# │   │   │   response_metadata={
# │   │   │   │   'token_usage': {
# │   │   │   │   │   'completion_tokens': 1066,
# │   │   │   │   │   'prompt_tokens': 462,
# │   │   │   │   │   'total_tokens': 1528,
# │   │   │   │   │   'completion_tokens_details': {
# │   │   │   │   │   │   'accepted_prediction_tokens': 0,
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'reasoning_tokens': 960,
# │   │   │   │   │   │   'rejected_prediction_tokens': 0
# │   │   │   │   │   },
# │   │   │   │   │   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
# │   │   │   │   },
# │   │   │   │   'model_provider': 'openai',
# │   │   │   │   'model_name': 'gpt-5-nano-2025-08-07',
# │   │   │   │   'system_fingerprint': None,
# │   │   │   │   'id': 'chatcmpl-EQffCpTDqcPk0MYZIdebcrwiTjAV5',
# │   │   │   │   'service_tier': 'default',
# │   │   │   │   'finish_reason': 'tool_calls',
# │   │   │   │   'logprobs': None
# │   │   │   },
# │   │   │   id='lc_run--01a0c5d3-d7c4-7f22-950e-3cd3c4520a97-0',
# │   │   │   tool_calls=[
# │   │   │   │   {
# │   │   │   │   │   'name': 'sql_query',
# │   │   │   │   │   'args': {
# │   │   │   │   │   │   'query': "SELECT a.Name AS ArtistName, SUM(il.Quantity) AS TotalSold\nFROM Artist a\nJOIN Album al ON al.ArtistId = a.ArtistId\nJOIN Track t ON t.AlbumId = al.AlbumId\nJOIN InvoiceLine il ON il.TrackId = t.TrackId\nWHERE a.Name LIKE 'S%'\nGROUP BY a.Name\nORDER BY TotalSold DESC\nLIMIT 1;"
# │   │   │   │   │   },
# │   │   │   │   │   'id': 'call_LnKc9vQRRvtiVTYSDkDf7yNC',
# │   │   │   │   │   'type': 'tool_call'
# │   │   │   │   }
# │   │   │   ],
# │   │   │   invalid_tool_calls=[],
# │   │   │   usage_metadata={
# │   │   │   │   'input_tokens': 462,
# │   │   │   │   'output_tokens': 1066,
# │   │   │   │   'total_tokens': 1528,
# │   │   │   │   'input_token_details': {'audio': 0, 'cache_read': 0},
# │   │   │   │   'output_token_details': {'audio': 0, 'reasoning': 960}
# │   │   │   }
# │   │   ),
# │   │   ToolMessage(
# │   │   │   content="[('Smashing Pumpkins', 24)]",
# │   │   │   name='sql_query',
# │   │   │   id='c023dd32-c16d-4365-b9cb-f35139fe137d',
# │   │   │   tool_call_id='call_LnKc9vQRRvtiVTYSDkDf7yNC'
# │   │   ),
# │   │   AIMessage(
# │   │   │   content="Smashing Pumpkins — 24 units sold (most popular among artists whose name starts with 'S'). \n\nIf you’d like, I can show the full top list for all 'S' artists.",
# │   │   │   additional_kwargs={'refusal': None},
# │   │   │   response_metadata={
# │   │   │   │   'token_usage': {
# │   │   │   │   │   'completion_tokens': 562,
# │   │   │   │   │   'prompt_tokens': 583,
# │   │   │   │   │   'total_tokens': 1145,
# │   │   │   │   │   'completion_tokens_details': {
# │   │   │   │   │   │   'accepted_prediction_tokens': 0,
# │   │   │   │   │   │   'audio_tokens': 0,
# │   │   │   │   │   │   'reasoning_tokens': 512,
# │   │   │   │   │   │   'rejected_prediction_tokens': 0
# │   │   │   │   │   },
# │   │   │   │   │   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
# │   │   │   │   },
# │   │   │   │   'model_provider': 'openai',
# │   │   │   │   'model_name': 'gpt-5-nano-2025-08-07',
# │   │   │   │   'system_fingerprint': None,
# │   │   │   │   'id': 'chatcmpl-EQffKJazFfgiKlM0AocQ8igDT4FvM',
# │   │   │   │   'service_tier': 'default',
# │   │   │   │   'finish_reason': 'stop',
# │   │   │   │   'logprobs': None
# │   │   │   },
# │   │   │   id='lc_run--01a0c5d3-f824-71a3-b616-a09a253b8b0a-0',
# │   │   │   tool_calls=[],
# │   │   │   invalid_tool_calls=[],
# │   │   │   usage_metadata={
# │   │   │   │   'input_tokens': 583,
# │   │   │   │   'output_tokens': 562,
# │   │   │   │   'total_tokens': 1145,
# │   │   │   │   'input_token_details': {'audio': 0, 'cache_read': 0},
# │   │   │   │   'output_token_details': {'audio': 0, 'reasoning': 512}
# │   │   │   }
# │   │   )
# │   ]
# }
